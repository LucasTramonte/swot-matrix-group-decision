# %% [markdown]
# PO/ER460 - Multi-criteria analysis course at Unicamp
#
# Selecting and ordering elements of the swot matrix through a multicriteria and group decision-making approach
#
# - Augusto Chebel Machado (231762)
# - Émerson José Ferri
# - Lucas Tramonte (182697)

# %% [markdown]
# # What does this code do?

# %% [markdown]
# - Using the PROMETHEE method, we rank each quadrant of the SWOT matrix (Opportunities, Threats, Weaknesses and Strengths);
# - Each decision-maker generates their own ranking;
# - After the individual ranking, using the Borda and Condorcet methods for group decisions, the rankings are generated for the group of decision-makers.

# %% [markdown]
# #  Libraries

# %%
import pandas as pd
import numpy as np
import condorcet

# %% [markdown]
# # Functions

# %% [markdown]
# ## Defining functions for the PROMETHEE Method

# %%
def f_pref(df, criterio, tipo, func='usual', q=0, p=0):
  n_alt = len(df)
  m = np.zeros([n_alt, n_alt])
  for i in range(0, n_alt):
    for j in range(0, n_alt):
      if tipo == 'max':
        d = df[criterio][i] - df[criterio][j]
      elif tipo == 'min':
        d = df[criterio][j] - df[criterio][i]

      if func == 'usual':
        if d <= 0:
          m[i][j] = 0
        else:
          m[i][j] = 1

      if func == 'U':
        if d <= q:
          m[i][j] = 0
        else:
          m[i][j] = 1

      if func == 'níveis':
        if d <= 0:
          m[i][j] = 0
        elif q < d <= p:
          m[i][j] = 1/2
        else:
          m[i][j] = 1

      if func == 'linear':
        if d <= q:
          m[i][j] = 0
        elif q < d <= p:
          m[i][j] = (d-q)/(p-q)
        else:
          m[i][j] = 1

  return m

# flow calculation
def fluxo_pos(M):
  fluxo_pos = []
  for i in range(0, len(M)):
    phi = sum(M[i])/(len(M)-1)
    fluxo_pos.append(phi)
  return np.array(fluxo_pos)

def fluxo_neg(M):
  fluxo_neg = []
  for j in range(0, len(M)):
    phi = sum(M[...,j])/(len(M)-1)
    fluxo_neg.append(phi)
  return np.array(fluxo_neg)

def fluxo_liq(fluxo_pos, fluxo_neg):
  fluxo_liq = fluxo_pos - fluxo_neg
  return fluxo_liq

# %% [markdown]
# ## Defining functions for the Condorcet Method

# %%
def voto(lista_df):
  votos = []
  for df in lista_df:
    voto_decisor = {}
    for i in range(0, len(df)):
      voto_decisor.update({df.index.values[i] : i+1})
    votos.append(voto_decisor)
  return votos

# %% [markdown]
# # Read data

# %% [markdown]
# ### Opportunities

# %%
oport_a1 = pd.read_excel('Assets\Datasets\PO_ER460 - Opportunities.xlsx', sheet_name=0)
oport_a2 = pd.read_excel('Assets\Datasets\PO_ER460 - Opportunities.xlsx', sheet_name=1)
oport_a3 = pd.read_excel('Assets\Datasets\PO_ER460 - Opportunities.xlsx', sheet_name=2)
oport_a4 = pd.read_excel('Assets\Datasets\PO_ER460 - Opportunities.xlsx', sheet_name=3)
oport_a5 = pd.read_excel('Assets\Datasets\PO_ER460 - Opportunities.xlsx', sheet_name=4)
oport_a6 = pd.read_excel('Assets\Datasets\PO_ER460 - Opportunities.xlsx', sheet_name=5)
oport_a7 = pd.read_excel('Assets\Datasets\PO_ER460 - Opportunities.xlsx', sheet_name=6)
oport_a8 = pd.read_excel('Assets\Datasets\PO_ER460 - Opportunities.xlsx', sheet_name=7)
oport_a9 = pd.read_excel('Assets\Datasets\PO_ER460 - Opportunities.xlsx', sheet_name=8)
oport_a10 = pd.read_excel('Assets\Datasets\PO_ER460 - Opportunities.xlsx', sheet_name=9)
oport_a11 = pd.read_excel('Assets\Datasets\PO_ER460 - Opportunities.xlsx', sheet_name=10)

# %%
# making the alternatives like indexes
def indice(df):
  df = df.set_index('Alternativas/Critérios')
  df.index.names = [None]
  return df

oport_a1 = indice(oport_a1)
oport_a2 = indice(oport_a2)
oport_a3 = indice(oport_a3)
oport_a4 = indice(oport_a4)
oport_a5 = indice(oport_a5)
oport_a6 = indice(oport_a6)
oport_a7 = indice(oport_a7)
oport_a8 = indice(oport_a8)
oport_a9 = indice(oport_a9)
oport_a10 = indice(oport_a10)
oport_a11 = indice(oport_a11)

# %%
# creating a numerical scale and passing it to df
def escala(df):
  dic = {'Muito Alto':5, 'Alto':4 , 'Médio':3, 'Baixo':2, 'Muito Baixo':1}
  df['Probabilidade'] = df['Probabilidade'].map(dic)
  df['Custo'] = df['Custo'].map(dic)
  df['Benefício'] = df['Benefício'].map(dic)
  df['Visão'] = df['Visão'].map(dic)
  return df

oport_a1 = escala(oport_a1)
oport_a2 = escala(oport_a2)
oport_a3 = escala(oport_a3)
oport_a4 = escala(oport_a4)
oport_a5 = escala(oport_a5)
oport_a6 = escala(oport_a6)
oport_a7 = escala(oport_a7)
oport_a8 = escala(oport_a8)
oport_a9 = escala(oport_a9)
oport_a10 = escala(oport_a10)
oport_a11 = escala(oport_a11)

# %%
# creating function to calculate preference matrix M
def M_oport(df, w):
  m_fortes = f_pref(df, 'Pontos Fortes', 'linear', 'max', q=1, p=4)
  m_fracos = f_pref(df, 'Pontos Fracos', 'linear', 'min', q=1, p=4)
  m_prob = f_pref(df, 'Probabilidade', 'max')
  m_custo = f_pref(df, 'Custo', 'min')
  m_benef = f_pref(df, 'Benefício', 'max')
  m_visao = f_pref(df, 'Visão', 'max')

  matrizes = [m_fortes, m_fracos, m_prob, m_custo, m_benef, m_visao]

  M = 0
  for i in range(0, len(matrizes)):
    M = M + w[i]*matrizes[i]

  return M

# vector of weights
w_oport = [0.21, 0.09, 0.13, 0.11, 0.12, 0.34]

# calculation of preference matrices for each decision-maker (opportunities):
M_a1 = M_oport(oport_a1, w_oport)
M_a2 = M_oport(oport_a2, w_oport)
M_a3 = M_oport(oport_a3, w_oport)
M_a4 = M_oport(oport_a4, w_oport)
M_a5 = M_oport(oport_a5, w_oport)
M_a6 = M_oport(oport_a6, w_oport)
M_a7 = M_oport(oport_a7, w_oport)
M_a8 = M_oport(oport_a8, w_oport)
M_a9 = M_oport(oport_a9, w_oport)
M_a10 = M_oport(oport_a10, w_oport)
M_a11 = M_oport(oport_a11, w_oport)
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_16368\2012082991.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   d = df[criterio][i] - df[criterio][j]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_16368\2012082991.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   d = df[criterio][j] - df[criterio][i]

# %%
# calculating the net flow
def fl_oport(M):
  fl = fluxo_liq(fluxo_pos(M), fluxo_neg(M))
  return fl

fl_a1 = fl_oport(M_a1)
fl_a2 = fl_oport(M_a2)
fl_a3 = fl_oport(M_a3)
fl_a4 = fl_oport(M_a4)
fl_a5 = fl_oport(M_a5)
fl_a6 = fl_oport(M_a6)
fl_a7 = fl_oport(M_a7)
fl_a8 = fl_oport(M_a8)
fl_a9 = fl_oport(M_a9)
fl_a10 = fl_oport(M_a10)
fl_a11 = fl_oport(M_a11)

# %%
# function for sorting
def ordenamento(decisor, df, fl):
  # generating a dictionary for ranking
  rank = {}
  for i in range(0, len(df)):
    rank.update({df.index.values[i] : fl[i]})

  tabela = pd.DataFrame(pd.Series(rank), columns=['Fluxo Líquido'])

  tabela = tabela.sort_values(by='Fluxo Líquido', ascending=False)

  ord = []
  for i in range(0, len(df)):
    ord.append(i+1)

  tabela[f'Rank D{decisor}'] = ord

  return tabela

# %%
print('Avaliador 1:')
print(ordenamento(1, oport_a1, fl_a1))
print(80*'-')
print('Avaliador 2:')
print(ordenamento(2, oport_a2, fl_a2))
print(80*'-')
print('Avaliador 3:')
print(ordenamento(3, oport_a3, fl_a3))
print(80*'-')
print('Avaliador 4:')
print(ordenamento(4, oport_a4, fl_a4))
print(80*'-')
print('Avaliador 5:')
print(ordenamento(5, oport_a5, fl_a5))
print(80*'-')
print('Avaliador 6:')
print(ordenamento(6, oport_a6, fl_a6))
print(80*'-')
print('Avaliador 7:')
print(ordenamento(7, oport_a7, fl_a7))
print(80*'-')
print('Avaliador 8:')
print(ordenamento(8, oport_a8, fl_a8))
print(80*'-')
print('Avaliador 9:')
print(ordenamento(9, oport_a9, fl_a9))
print(80*'-')
print('Avaliador 10:')
print(ordenamento(10, oport_a10, fl_a10))
print(80*'-')
print('Avaliador 11:')
print(ordenamento(11, oport_a11, fl_a11))
print(80*'-')
# Out:
# Avaliador 1:
#                                                     Fluxo Líquido  Rank D1
# Demanda regional por um novo serviço de atenção...       0.384286        1
# Políticas públicas: financiamento (emendas) e i...       0.118571        2
# Ambiente interno favorável à coordenação mútua           0.118571        3
# Desenvolvimento de novas tecnologias da informação       0.004286        4
# Prestígio social da Unicamp                             -0.007143        5
# Nova lei de licitação 14.133/2021                       -0.072857        6
# Legislação favorável a parcerias público-privada        -0.210000        7
# Gestão de RH: aperfeiçoamento dos métodos de co...      -0.335714        8
# --------------------------------------------------------------------------------
# Avaliador 2:
#                                                     Fluxo Líquido  Rank D2
# Nova lei de licitação 14.133/2021                        0.384286        1
# Demanda regional por um novo serviço de atenção...       0.278571        2
# Prestígio social da Unicamp                              0.045714        3
# Políticas públicas: financiamento (emendas) e i...       0.034286        4
# Ambiente interno favorável à coordenação mútua           0.034286        5
# Gestão de RH: aperfeiçoamento dos métodos de co...       0.008571        6
# Legislação favorável a parcerias público-privada        -0.392857        7
# Desenvolvimento de novas tecnologias da informação      -0.392857        8
# --------------------------------------------------------------------------------
# Avaliador 3:
#                                                     Fluxo Líquido  Rank D3
# Demanda regional por um novo serviço de atenção...       0.281429        1
# Ambiente interno favorável à coordenação mútua           0.165714        2
# Desenvolvimento de novas tecnologias da informação       0.138571        3
# Políticas públicas: financiamento (emendas) e i...       0.132857        4
# Nova lei de licitação 14.133/2021                        0.012857        5
# Legislação favorável a parcerias público-privada        -0.015714        6
# Prestígio social da Unicamp                             -0.290000        7
# Gestão de RH: aperfeiçoamento dos métodos de co...      -0.425714        8
# --------------------------------------------------------------------------------
# Avaliador 4:
#                                                     Fluxo Líquido  Rank D4
# Políticas públicas: financiamento (emendas) e i...       0.298571        1
# Prestígio social da Unicamp                              0.205714        2
# Ambiente interno favorável à coordenação mútua           0.150000        3
# Demanda regional por um novo serviço de atenção...      -0.011429        4
# Nova lei de licitação 14.133/2021                       -0.041429        5
# Desenvolvimento de novas tecnologias da informação      -0.068571        6
# Legislação favorável a parcerias público-privada        -0.254286        7
# Gestão de RH: aperfeiçoamento dos métodos de co...      -0.278571        8
# --------------------------------------------------------------------------------
# Avaliador 5:
#                                                     Fluxo Líquido  Rank D5
# Prestígio social da Unicamp                              0.408571        1
# Demanda regional por um novo serviço de atenção...       0.357143        2
# Desenvolvimento de novas tecnologias da informação       0.051429        3
# Ambiente interno favorável à coordenação mútua          -0.042857        4
# Gestão de RH: aperfeiçoamento dos métodos de co...      -0.102857        5
# Legislação favorável a parcerias público-privada        -0.162857        6
# Políticas públicas: financiamento (emendas) e i...      -0.195714        7
# Nova lei de licitação 14.133/2021                       -0.312857        8
# --------------------------------------------------------------------------------
# Avaliador 6:
#                                                     Fluxo Líquido  Rank D6
# Prestígio social da Unicamp                              0.507143        1
# Gestão de RH: aperfeiçoamento dos métodos de co...       0.170000        2
# Nova lei de licitação 14.133/2021                        0.002857        3
# Demanda regional por um novo serviço de atenção...      -0.031429        4
# Políticas públicas: financiamento (emendas) e i...      -0.045714        5
# Desenvolvimento de novas tecnologias da informação      -0.124286        6
# Legislação favorável a parcerias público-privada        -0.157143        7
# Ambiente interno favorável à coordenação mútua          -0.321429        8
# --------------------------------------------------------------------------------
# Avaliador 7:
#                                                     Fluxo Líquido  Rank D7
# Legislação favorável a parcerias público-privada         0.398571        1
# Demanda regional por um novo serviço de atenção...       0.181429        2
# Prestígio social da Unicamp                              0.155714        3
# Nova lei de licitação 14.133/2021                       -0.041429        4
# Gestão de RH: aperfeiçoamento dos métodos de co...      -0.090000        5
# Desenvolvimento de novas tecnologias da informação      -0.158571        6
# Ambiente interno favorável à coordenação mútua          -0.161429        7
# Políticas públicas: financiamento (emendas) e i...      -0.284286        8
# --------------------------------------------------------------------------------
# Avaliador 8:
#                                                     Fluxo Líquido  Rank D8
# Prestígio social da Unicamp                              0.367143        1
# Gestão de RH: aperfeiçoamento dos métodos de co...       0.218571        2
# Ambiente interno favorável à coordenação mútua          -0.021429        3
# Desenvolvimento de novas tecnologias da informação      -0.021429        4
# Legislação favorável a parcerias público-privada        -0.032857        5
# Demanda regional por um novo serviço de atenção...      -0.158571        6
# Políticas públicas: financiamento (emendas) e i...      -0.170000        7
# Nova lei de licitação 14.133/2021                       -0.181429        8
# --------------------------------------------------------------------------------
# Avaliador 9:
#                                                     Fluxo Líquido  Rank D9
# Gestão de RH: aperfeiçoamento dos métodos de co...       0.220000        1
# Prestígio social da Unicamp                              0.220000        2
# Ambiente interno favorável à coordenação mútua           0.071429        3
# Legislação favorável a parcerias público-privada         0.071429        4
# Políticas públicas: financiamento (emendas) e i...       0.065714        5
# Nova lei de licitação 14.133/2021                       -0.091429        6
# Demanda regional por um novo serviço de atenção...      -0.191429        7
# Desenvolvimento de novas tecnologias da informação      -0.365714        8
# --------------------------------------------------------------------------------
# Avaliador 10:
#                                                     Fluxo Líquido  Rank D10
# Demanda regional por um novo serviço de atenção...       0.222857         1
# Políticas públicas: financiamento (emendas) e i...       0.222857         2
# Prestígio social da Unicamp                              0.172857         3
# Desenvolvimento de novas tecnologias da informação       0.041429         4
# Ambiente interno favorável à coordenação mútua           0.032857         5
# Legislação favorável a parcerias público-privada        -0.070000         6
# Nova lei de licitação 14.133/2021                       -0.161429         7
# Gestão de RH: aperfeiçoamento dos métodos de co...      -0.461429         8
# --------------------------------------------------------------------------------
# Avaliador 11:
#                                                     Fluxo Líquido  Rank D11
# Demanda regional por um novo serviço de atenção...       0.325714         1
# Prestígio social da Unicamp                              0.078571         2
# Nova lei de licitação 14.133/2021                        0.035714         3
# Legislação favorável a parcerias público-privada        -0.057143         4
# Políticas públicas: financiamento (emendas) e i...      -0.058571         5
# Desenvolvimento de novas tecnologias da informação      -0.070000         6
# Gestão de RH: aperfeiçoamento dos métodos de co...      -0.102857         7
# Ambiente interno favorável à coordenação mútua          -0.151429         8
# --------------------------------------------------------------------------------

# %%
# generating the tables for each decision-maker (opportunities)

ordem_oport_a1 = ordenamento(1, oport_a1, fl_a1)
ordem_oport_a2 = ordenamento(2, oport_a2, fl_a2)
ordem_oport_a3 = ordenamento(3, oport_a3, fl_a3)
ordem_oport_a4 = ordenamento(4, oport_a4, fl_a4)
ordem_oport_a5 = ordenamento(5, oport_a5, fl_a5)
ordem_oport_a6 = ordenamento(6, oport_a6, fl_a6)
ordem_oport_a7 = ordenamento(7, oport_a7, fl_a7)
ordem_oport_a8 = ordenamento(8, oport_a8, fl_a8)
ordem_oport_a9 = ordenamento(9, oport_a9, fl_a9)
ordem_oport_a10 = ordenamento(10, oport_a10, fl_a10)
ordem_oport_a11 = ordenamento(11, oport_a11, fl_a11)

# creating a dataframe with the rankings of all the decision-makers:
oportuni = pd.concat([ordem_oport_a1, ordem_oport_a2, ordem_oport_a3, ordem_oport_a4, ordem_oport_a5,ordem_oport_a6,ordem_oport_a7,ordem_oport_a8,ordem_oport_a9,ordem_oport_a10,ordem_oport_a11], axis=1)
oportuni
oportuni = oportuni.drop(['Fluxo Líquido'], axis=1)
oportuni
# Out:
#                                                     Rank D1  Rank D2  Rank D3  \
# Demanda regional por um novo serviço de atenção...        1        2        1
# Políticas públicas: financiamento (emendas) e i...        2        4        4
# Ambiente interno favorável à coordenação mútua            3        5        2
# Desenvolvimento de novas tecnologias da informação        4        8        3
# Prestígio social da Unicamp                               5        3        7
# Nova lei de licitação 14.133/2021                         6        1        5
# Legislação favorável a parcerias público-privada          7        7        6
# Gestão de RH: aperfeiçoamento dos métodos de co...        8        6        8
#
#                                                     Rank D4  Rank D5  Rank D6  \
# Demanda regional por um novo serviço de atenção...        4        2        4
# Políticas públicas: financiamento (emendas) e i...        1        7        5
# Ambiente interno favorável à coordenação mútua            3        4        8
# Desenvolvimento de novas tecnologias da informação        6        3        6
# Prestígio social da Unicamp                               2        1        1
# Nova lei de licitação 14.133/2021                         5        8        3
# Legislação favorável a parcerias público-privada          7        6        7
# Gestão de RH: aperfeiçoamento dos métodos de co...        8        5        2
#
#                                                     Rank D7  Rank D8  Rank D9  \
# Demanda regional por um novo serviço de atenção...        2        6        7
# Políticas públicas: financiamento (emendas) e i...        8        7        5
# Ambiente interno favorável à coordenação mútua            7        3        3
# Desenvolvimento de novas tecnologias da informação        6        4        8
# Prestígio social da Unicamp                               3        1        2
# Nova lei de licitação 14.133/2021                         4        8        6
# Legislação favorável a parcerias público-privada          1        5        4
# Gestão de RH: aperfeiçoamento dos métodos de co...        5        2        1
#
#                                                     Rank D10  Rank D11
# Demanda regional por um novo serviço de atenção...         1         1
# Políticas públicas: financiamento (emendas) e i...         2         5
# Ambiente interno favorável à coordenação mútua             5         8
# Desenvolvimento de novas tecnologias da informação         4         6
# Prestígio social da Unicamp                                3         2
# Nova lei de licitação 14.133/2021                          7         3
# Legislação favorável a parcerias público-privada           6         4
# Gestão de RH: aperfeiçoamento dos métodos de co...         8         7

# %% [markdown]
# # Group Decision (Borda)

# %%
# creating a scale for the border
borda_oport = {}
for i in range(0, len(oportuni)):
  borda_oport.update({i+1: (len(oportuni)-i)})

peso_dirigente = 1.2
borda_oport_dirig = {}
for i in range(0, len(oportuni)):
  borda_oport_dirig.update({i+1: (len(oportuni)-i)*peso_dirigente})

# replacing the sort values with the Edge scale value
# Ex: (1,2,3) will become (3,2,1)
for i in oportuni.columns:
  if i == oportuni.columns[0]: # se o decisor for a dirigente (peso maior)
    oportuni[i] = oportuni[i].map(borda_oport_dirig)
  else:
    oportuni[i] = oportuni[i].map(borda_oport)

# adding up the values of each alternative
oportuni['Valor'] = oportuni.sum(axis=1)

oport_final = pd.DataFrame(oportuni['Valor'])
oport_final = oport_final.sort_values(by='Valor', ascending=False)

ord = []
for i in range(0, len(oport_final)):
  ord.append(f'{i+1}°')

oport_final['Ordem Final (Borda)'] = ord
oport_final
# Out:
#                                                     Valor Ordem Final (Borda)
# Prestígio social da Unicamp                          69.8                  1°
# Demanda regional por um novo serviço de atenção...   69.6                  2°
# Políticas públicas: financiamento (emendas) e i...   50.4                  3°
# Ambiente interno favorável à coordenação mútua       49.2                  4°
# Nova lei de licitação 14.133/2021                    43.6                  5°
# Desenvolvimento de novas tecnologias da informação   42.0                  6°
# Legislação favorável a parcerias público-privada     39.4                  7°
# Gestão de RH: aperfeiçoamento dos métodos de co...   39.2                  8°

# %% [markdown]
# Group decision-making (Condorcet)

# %%
ordem_oport_a1 = ordenamento(1, oport_a1, fl_a1)
ordem_oport_a2 = ordenamento(2, oport_a2, fl_a2)
ordem_oport_a3 = ordenamento(3, oport_a3, fl_a3)
ordem_oport_a4 = ordenamento(4, oport_a4, fl_a4)
ordem_oport_a5 = ordenamento(5, oport_a5, fl_a5)
ordem_oport_a6 = ordenamento(6, oport_a6, fl_a6)
ordem_oport_a7 = ordenamento(7, oport_a7, fl_a7)
ordem_oport_a8 = ordenamento(8, oport_a8, fl_a8)
ordem_oport_a9 = ordenamento(9, oport_a9, fl_a9)
ordem_oport_a10 = ordenamento(10, oport_a10, fl_a10)
ordem_oport_a11 = ordenamento(11, oport_a11, fl_a11)

candidatos = ordem_oport_a1.index.values
candidatos = list(candidatos)

lista_oport = [ordem_oport_a1, ordem_oport_a2, ordem_oport_a3, ordem_oport_a4, ordem_oport_a5, ordem_oport_a6,ordem_oport_a7,ordem_oport_a8,ordem_oport_a9,ordem_oport_a10,ordem_oport_a11]
votos = voto(lista_oport)

# using condorcet library functions to define sorting
evaluator = condorcet.CondorcetEvaluator(candidates=candidatos, votes=votos)
winners, rest_of_table = evaluator.get_n_winners(len(ordem_oport_a1))

oport_condorcet = pd.DataFrame(index=winners)

ord = []
for i in range(0, len(oport_condorcet)):
  ord.append(f'{i+1}°')
oport_condorcet['Ordem Final (Condorcet)'] = ord

oport_condorcet
# Out:
#                                                    Ordem Final (Condorcet)
# Demanda regional por um novo serviço de atenção...                      1°
# Prestígio social da Unicamp                                             2°
# Políticas públicas: financiamento (emendas) e i...                      3°
# Ambiente interno favorável à coordenação mútua                          4°
# Nova lei de licitação 14.133/2021                                       5°
# Desenvolvimento de novas tecnologias da informação                      6°
# Legislação favorável a parcerias público-privada                        7°
# Gestão de RH: aperfeiçoamento dos métodos de co...                      8°

# %% [markdown]
# # Threats

# %%
# Importing problem data (threats)

ameaça_a1 = pd.read_excel('Assets\Datasets\PO_ER460 - Threats.xlsx', sheet_name=0)
ameaça_a2 = pd.read_excel('Assets\Datasets\PO_ER460 - Threats.xlsx', sheet_name=1)
ameaça_a3 = pd.read_excel('Assets\Datasets\PO_ER460 - Threats.xlsx', sheet_name=2)
ameaça_a4 = pd.read_excel('Assets\Datasets\PO_ER460 - Threats.xlsx', sheet_name=3)
ameaça_a5 = pd.read_excel('Assets\Datasets\PO_ER460 - Threats.xlsx', sheet_name=4)
ameaça_a6 = pd.read_excel('Assets\Datasets\PO_ER460 - Threats.xlsx', sheet_name=5)
ameaça_a7 = pd.read_excel('Assets\Datasets\PO_ER460 - Threats.xlsx', sheet_name=6)
ameaça_a8 = pd.read_excel('Assets\Datasets\PO_ER460 - Threats.xlsx', sheet_name=7)
ameaça_a9 = pd.read_excel('Assets\Datasets\PO_ER460 - Threats.xlsx', sheet_name=8)
ameaça_a10 = pd.read_excel('Assets\Datasets\PO_ER460 - Threats.xlsx', sheet_name=9)
ameaça_a11 = pd.read_excel('Assets\Datasets\PO_ER460 - Threats.xlsx', sheet_name=10)

# %%
# making the alternatives like indexes
def indice(df):
  df = df.set_index('Alternativas/Critérios')
  df.index.names = [None]
  return df

ameaça_a1 = indice(ameaça_a1)
ameaça_a2 = indice(ameaça_a2)
ameaça_a3 = indice(ameaça_a3)
ameaça_a4 = indice(ameaça_a4)
ameaça_a5 = indice(ameaça_a5)
ameaça_a6 = indice(ameaça_a6)
ameaça_a7 = indice(ameaça_a7)
ameaça_a8 = indice(ameaça_a8)
ameaça_a9 = indice(ameaça_a9)
ameaça_a10 = indice(ameaça_a10)
ameaça_a11 = indice(ameaça_a11)

# %%
# criando uma escala numérica e passando para o df
def escala(df):
  dic = {'Muito Alto':5, 'Alto':4 , 'Médio':3, 'Baixo':2, 'Muito Baixo':1}
  df['Probabilidade'] = df['Probabilidade'].map(dic)
  df['Custo'] = df['Custo'].map(dic)
  df['Impacto'] = df['Impacto'].map(dic)
  df['Visão'] = df['Visão'].map(dic)
  return df

ameaça_a1 = escala(ameaça_a1)
ameaça_a2 = escala(ameaça_a2)
ameaça_a3 = escala(ameaça_a3)
ameaça_a4 = escala(ameaça_a4)
ameaça_a5 = escala(ameaça_a5)
ameaça_a6 = escala(ameaça_a6)
ameaça_a7 = escala(ameaça_a7)
ameaça_a8 = escala(ameaça_a8)
ameaça_a9 = escala(ameaça_a9)
ameaça_a10 = escala(ameaça_a10)
ameaça_a11 = escala(ameaça_a11)

# %%
# creating function to calculate preference matrix M
def M_ameaca(df, w):
  m_fracos = f_pref(df, 'Pontos Fracos', 'min', 'linear', q=1, p=4)
  m_fortes = f_pref(df, 'Pontos Fortes', 'max', 'linear', q=1, p=4)
  m_prob = f_pref(df, 'Probabilidade', 'max')
  m_custo = f_pref(df, 'Custo', 'min')
  m_impac = f_pref(df, 'Impacto', 'max')
  m_visao = f_pref(df, 'Visão', 'max')

  matrizes = [m_fortes, m_fracos, m_prob, m_custo, m_impac, m_visao]

  M = 0
  for i in range(0, len(matrizes)):
    M = M + w[i]*matrizes[i]

  return M

# vector of weights
w_ameaça = [0.18, 0.12, 0.18, 0.08, 0.12, 0.32]

# calculation of preference matrices for each decision-maker (threats):
M_a1 = M_ameaca(ameaça_a1, w_ameaça)
M_a2 = M_ameaca(ameaça_a2, w_ameaça)
M_a3 = M_ameaca(ameaça_a3, w_ameaça)
M_a4 = M_ameaca(ameaça_a4, w_ameaça)
M_a5 = M_ameaca(ameaça_a5, w_ameaça)
M_a6 = M_ameaca(ameaça_a6, w_ameaça)
M_a7 = M_ameaca(ameaça_a7, w_ameaça)
M_a8 = M_ameaca(ameaça_a8, w_ameaça)
M_a9 = M_ameaca(ameaça_a9, w_ameaça)
M_a10 = M_ameaca(ameaça_a10, w_ameaça)
M_a11 = M_ameaca(ameaça_a11, w_ameaça)
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_16368\2012082991.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   d = df[criterio][j] - df[criterio][i]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_16368\2012082991.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   d = df[criterio][i] - df[criterio][j]

# %%
# calculating the net flow
def fl_ameaca(M):
  fl = fluxo_liq(fluxo_pos(M), fluxo_neg(M))
  return fl

fl_a1 = fl_ameaca(M_a1)
fl_a2 = fl_ameaca(M_a2)
fl_a3 = fl_ameaca(M_a3)
fl_a4 = fl_ameaca(M_a4)
fl_a5 = fl_ameaca(M_a5)
fl_a6 = fl_ameaca(M_a6)
fl_a7 = fl_ameaca(M_a7)
fl_a8 = fl_ameaca(M_a8)
fl_a9 = fl_ameaca(M_a9)
fl_a10 = fl_ameaca(M_a10)
fl_a11 = fl_ameaca(M_a11)

# %%
# function for sorting
def ordenamento(decisor, df, fl):
  # generating a dictionary for ranking
  rank = {}
  for i in range(0, len(df)):
    rank.update({df.index.values[i] : fl[i]})

  tabela = pd.DataFrame(pd.Series(rank), columns=['Fluxo Líquido'])

  tabela = tabela.sort_values(by='Fluxo Líquido', ascending=False)

  ord = []
  for i in range(0, len(df)):
    ord.append(i+1)

  tabela[f'Rank D{decisor}'] = ord

  return tabela

# %%
print('Avaliador 1:')
print(ordenamento(1, ameaça_a1, fl_a1))
print(80*'-')
print('Avaliador 2:')
print(ordenamento(2, ameaça_a2, fl_a2))
print(80*'-')
print('Avaliador 3:')
print(ordenamento(3, ameaça_a3, fl_a3))
print(80*'-')
print('Avaliador 4:')
print(ordenamento(4, ameaça_a4, fl_a4))
print(80*'-')
print('Avaliador 5:')
print(ordenamento(5, ameaça_a5, fl_a5))
print(80*'-')
print('Avaliador 6:')
print(ordenamento(6, ameaça_a6, fl_a6))
print(80*'-')
print('Avaliador 7:')
print(ordenamento(7, ameaça_a7, fl_a7))
print(80*'-')
print('Avaliador 8:')
print(ordenamento(8, ameaça_a8, fl_a8))
print(80*'-')
print('Avaliador 9:')
print(ordenamento(9, ameaça_a9, fl_a9))
print(80*'-')
print('Avaliador 10:')
print(ordenamento(10, ameaça_a10, fl_a10))
print(80*'-')
print('Avaliador 11:')
print(ordenamento(11, ameaça_a11, fl_a11))
print(80*'-')
# Out:
# Avaliador 1:
#                                                     Fluxo Líquido  Rank D1
# Distorções existentes nos serviços de saúde cau...       0.235789        1
# Subfinanciamento do SUS                                  0.230526        2
# Administração Central insensível às demandas da...       0.204211        3
# Grau de independência de cada serviço de saúde ...       0.164211        4
# Instabilidade e inadequação dos recursos financ...       0.153684        5
# Ausência de interlocução do DGRH com a DEAS em ...       0.113684        6
# Sistemas informatizados da universidade e ausên...       0.082105        7
# Resistência das unidades próprias de Saúde à ce...       0.078947        8
# Fragilidades relacionadas ao modelo de gestão d...       0.063158        9
# Instabilidade do financiamento devido às mudanç...       0.049474       10
# Ponto eletrônico pode gerar processos trabalhis...       0.037895       11
# Readequações necessárias para o cumprimento da ...       0.030526       12
# Insuficiência do financiamento das unidades con...      -0.048421       13
# Fragilidade de políticas específicas do Estado ...      -0.077895       14
# Demandas excessivas dos órgãos de fiscalização ...      -0.110526       15
# Fragilidades relacionadas ao modelo de atenção ...      -0.126316       16
# Burocratização exacerbada de processos administ...      -0.189474       17
# Impacto dos processos de judicialização da Saúde        -0.289474       18
# Perda de conhecimentos intangíveis com os proce...      -0.300000       19
# CNPJ / CNES único                                       -0.302105       20
# --------------------------------------------------------------------------------
# Avaliador 2:
#                                                     Fluxo Líquido  Rank D2
# Resistência das unidades próprias de Saúde à ce...       0.404211        1
# Grau de independência de cada serviço de saúde ...       0.268421        2
# Ausência de interlocução do DGRH com a DEAS em ...       0.221053        3
# Perda de conhecimentos intangíveis com os proce...       0.217895        4
# Fragilidade de políticas específicas do Estado ...       0.146316        5
# Administração Central insensível às demandas da...       0.146316        6
# Sistemas informatizados da universidade e ausên...       0.146316        7
# Instabilidade e inadequação dos recursos financ...       0.146316        8
# Insuficiência do financiamento das unidades con...       0.146316        9
# Readequações necessárias para o cumprimento da ...      -0.049474       10
# CNPJ / CNES único                                       -0.051579       11
# Instabilidade do financiamento devido às mudanç...      -0.051579       12
# Ponto eletrônico pode gerar processos trabalhis...      -0.123158       13
# Burocratização exacerbada de processos administ...      -0.123158       14
# Distorções existentes nos serviços de saúde cau...      -0.137895       15
# Fragilidades relacionadas ao modelo de gestão d...      -0.137895       16
# Fragilidades relacionadas ao modelo de atenção ...      -0.203158       17
# Demandas excessivas dos órgãos de fiscalização ...      -0.269474       18
# Subfinanciamento do SUS                                 -0.274737       19
# Impacto dos processos de judicialização da Saúde        -0.421053       20
# --------------------------------------------------------------------------------
# Avaliador 3:
#                                                     Fluxo Líquido  Rank D3
# Resistência das unidades próprias de Saúde à ce...       0.463158        1
# Grau de independência de cada serviço de saúde ...       0.437895        2
# Fragilidades relacionadas ao modelo de atenção ...       0.394737        3
# Instabilidade do financiamento devido às mudanç...       0.283158        4
# Instabilidade e inadequação dos recursos financ...       0.276842        5
# Subfinanciamento do SUS                                  0.266316        6
# Insuficiência do financiamento das unidades con...       0.247368        7
# Fragilidade de políticas específicas do Estado ...       0.140000        8
# Administração Central insensível às demandas da...       0.107368        9
# Fragilidades relacionadas ao modelo de gestão d...       0.096842       10
# Sistemas informatizados da universidade e ausên...      -0.087368       11
# Readequações necessárias para o cumprimento da ...      -0.184211       12
# Burocratização exacerbada de processos administ...      -0.217895       13
# Ponto eletrônico pode gerar processos trabalhis...      -0.236842       14
# Impacto dos processos de judicialização da Saúde        -0.266316       15
# Demandas excessivas dos órgãos de fiscalização ...      -0.306316       16
# CNPJ / CNES único                                       -0.338947       17
# Ausência de interlocução do DGRH com a DEAS em ...      -0.346316       18
# Distorções existentes nos serviços de saúde cau...      -0.355789       19
# Perda de conhecimentos intangíveis com os proce...      -0.373684       20
# --------------------------------------------------------------------------------
# Avaliador 4:
#                                                     Fluxo Líquido  Rank D4
# Fragilidades relacionadas ao modelo de gestão d...       0.460000        1
# Administração Central insensível às demandas da...       0.197895        2
# Instabilidade do financiamento devido às mudanç...       0.194737        3
# Fragilidades relacionadas ao modelo de atenção ...       0.171579        4
# Resistência das unidades próprias de Saúde à ce...       0.134737        5
# CNPJ / CNES único                                        0.131579        6
# Grau de independência de cada serviço de saúde ...       0.100000        7
# Fragilidade de políticas específicas do Estado ...       0.088421        8
# Insuficiência do financiamento das unidades con...       0.068421        9
# Subfinanciamento do SUS                                  0.044211       10
# Instabilidade e inadequação dos recursos financ...       0.043158       11
# Burocratização exacerbada de processos administ...       0.003158       12
# Demandas excessivas dos órgãos de fiscalização ...      -0.003158       13
# Readequações necessárias para o cumprimento da ...      -0.030526       14
# Sistemas informatizados da universidade e ausên...      -0.055789       15
# Impacto dos processos de judicialização da Saúde        -0.187368       16
# Ausência de interlocução do DGRH com a DEAS em ...      -0.204211       17
# Distorções existentes nos serviços de saúde cau...      -0.353684       18
# Ponto eletrônico pode gerar processos trabalhis...      -0.376842       19
# Perda de conhecimentos intangíveis com os proce...      -0.426316       20
# --------------------------------------------------------------------------------
# Avaliador 5:
#                                                     Fluxo Líquido  Rank D5
# Grau de independência de cada serviço de saúde ...       0.330526        1
# Ponto eletrônico pode gerar processos trabalhis...       0.322105        2
# Fragilidades relacionadas ao modelo de gestão d...       0.313684        3
# Resistência das unidades próprias de Saúde à ce...       0.284211        4
# Fragilidades relacionadas ao modelo de atenção ...       0.267368        5
# Burocratização exacerbada de processos administ...       0.210526        6
# Subfinanciamento do SUS                                  0.197895        7
# Instabilidade e inadequação dos recursos financ...       0.192632        8
# Insuficiência do financiamento das unidades con...       0.192632        9
# Instabilidade do financiamento devido às mudanç...       0.137895       10
# Readequações necessárias para o cumprimento da ...       0.045263       11
# Demandas excessivas dos órgãos de fiscalização ...       0.044211       12
# Ausência de interlocução do DGRH com a DEAS em ...       0.007368       13
# Impacto dos processos de judicialização da Saúde        -0.006316       14
# Administração Central insensível às demandas da...      -0.268421       15
# Sistemas informatizados da universidade e ausên...      -0.271579       16
# Fragilidade de políticas específicas do Estado ...      -0.469474       17
# CNPJ / CNES único                                       -0.498947       18
# Distorções existentes nos serviços de saúde cau...      -0.500000       19
# Perda de conhecimentos intangíveis com os proce...      -0.531579       20
# --------------------------------------------------------------------------------
# Avaliador 6:
#                                                     Fluxo Líquido  Rank D6
# Sistemas informatizados da universidade e ausên...       0.344211        1
# Perda de conhecimentos intangíveis com os proce...       0.288421        2
# Demandas excessivas dos órgãos de fiscalização ...       0.226316        3
# Ausência de interlocução do DGRH com a DEAS em ...       0.167368        4
# Insuficiência do financiamento das unidades con...       0.167368        5
# Grau de independência de cada serviço de saúde ...       0.087368        6
# CNPJ / CNES único                                        0.076842        7
# Distorções existentes nos serviços de saúde cau...       0.075789        8
# Burocratização exacerbada de processos administ...       0.072632        9
# Resistência das unidades próprias de Saúde à ce...       0.056842       10
# Fragilidades relacionadas ao modelo de gestão d...       0.007368       11
# Subfinanciamento do SUS                                  0.003158       12
# Impacto dos processos de judicialização da Saúde        -0.018947       13
# Readequações necessárias para o cumprimento da ...      -0.082105       14
# Administração Central insensível às demandas da...      -0.151579       15
# Instabilidade e inadequação dos recursos financ...      -0.167368       16
# Fragilidade de políticas específicas do Estado ...      -0.204211       17
# Instabilidade do financiamento devido às mudanç...      -0.229474       18
# Fragilidades relacionadas ao modelo de atenção ...      -0.348421       19
# Ponto eletrônico pode gerar processos trabalhis...      -0.371579       20
# --------------------------------------------------------------------------------
# Avaliador 7:
#                                                     Fluxo Líquido  Rank D7
# Insuficiência do financiamento das unidades con...       0.485263        1
# Ausência de interlocução do DGRH com a DEAS em ...       0.454737        2
# Instabilidade do financiamento devido às mudanç...       0.430526        3
# Grau de independência de cada serviço de saúde ...       0.320000        4
# Instabilidade e inadequação dos recursos financ...       0.247368        5
# Sistemas informatizados da universidade e ausên...       0.150526        6
# Impacto dos processos de judicialização da Saúde         0.127368        7
# Demandas excessivas dos órgãos de fiscalização ...       0.097895        8
# Fragilidades relacionadas ao modelo de atenção ...       0.089474        9
# Administração Central insensível às demandas da...      -0.001053       10
# Resistência das unidades próprias de Saúde à ce...      -0.022105       11
# Fragilidade de políticas específicas do Estado ...      -0.043158       12
# Subfinanciamento do SUS                                 -0.105263       13
# Burocratização exacerbada de processos administ...      -0.138947       14
# Fragilidades relacionadas ao modelo de gestão d...      -0.167368       15
# Perda de conhecimentos intangíveis com os proce...      -0.263158       16
# Ponto eletrônico pode gerar processos trabalhis...      -0.284211       17
# Readequações necessárias para o cumprimento da ...      -0.342105       18
# CNPJ / CNES único                                       -0.498947       19
# Distorções existentes nos serviços de saúde cau...      -0.536842       20
# --------------------------------------------------------------------------------
# Avaliador 8:
#                                                     Fluxo Líquido  Rank D8
# Insuficiência do financiamento das unidades con...       0.285263        1
# Subfinanciamento do SUS                                  0.260000        2
# Instabilidade do financiamento devido às mudanç...       0.260000        3
# Instabilidade e inadequação dos recursos financ...       0.236842        4
# Impacto dos processos de judicialização da Saúde         0.232632        5
# Fragilidades relacionadas ao modelo de gestão d...       0.201053        6
# Fragilidades relacionadas ao modelo de atenção ...       0.190526        7
# Demandas excessivas dos órgãos de fiscalização ...       0.095789        8
# Administração Central insensível às demandas da...       0.028421        9
# CNPJ / CNES único                                        0.022105       10
# Resistência das unidades próprias de Saúde à ce...       0.020000       11
# Sistemas informatizados da universidade e ausên...      -0.024211       12
# Grau de independência de cada serviço de saúde ...      -0.114737       13
# Perda de conhecimentos intangíveis com os proce...      -0.167368       14
# Ponto eletrônico pode gerar processos trabalhis...      -0.198947       15
# Burocratização exacerbada de processos administ...      -0.209474       16
# Fragilidade de políticas específicas do Estado ...      -0.213684       17
# Ausência de interlocução do DGRH com a DEAS em ...      -0.268421       18
# Distorções existentes nos serviços de saúde cau...      -0.283158       19
# Readequações necessárias para o cumprimento da ...      -0.352632       20
# --------------------------------------------------------------------------------
# Avaliador 9:
#                                                     Fluxo Líquido  Rank D9
# Fragilidades relacionadas ao modelo de gestão d...       0.500000        1
# Resistência das unidades próprias de Saúde à ce...       0.404211        2
# Administração Central insensível às demandas da...       0.262105        3
# Fragilidade de políticas específicas do Estado ...       0.209474        4
# Fragilidades relacionadas ao modelo de atenção ...       0.208421        5
# Instabilidade do financiamento devido às mudanç...       0.185263        6
# Impacto dos processos de judicialização da Saúde         0.166316        7
# Instabilidade e inadequação dos recursos financ...       0.157895        8
# Insuficiência do financiamento das unidades con...       0.157895        9
# Grau de independência de cada serviço de saúde ...       0.118947       10
# Subfinanciamento do SUS                                  0.082105       11
# Burocratização exacerbada de processos administ...      -0.116842       12
# Perda de conhecimentos intangíveis com os proce...      -0.156842       13
# Ponto eletrônico pode gerar processos trabalhis...      -0.195789       14
# Readequações necessárias para o cumprimento da ...      -0.245263       15
# Ausência de interlocução do DGRH com a DEAS em ...      -0.285263       16
# CNPJ / CNES único                                       -0.333684       17
# Demandas excessivas dos órgãos de fiscalização ...      -0.346316       18
# Sistemas informatizados da universidade e ausên...      -0.386316       19
# Distorções existentes nos serviços de saúde cau...      -0.386316       20
# --------------------------------------------------------------------------------
# Avaliador 10:
#                                                     Fluxo Líquido  Rank D10
# Fragilidade de políticas específicas do Estado ...       0.430526         1
# Instabilidade do financiamento devido às mudanç...       0.430526         2
# Instabilidade e inadequação dos recursos financ...       0.430526         3
# Insuficiência do financiamento das unidades con...       0.430526         4
# Subfinanciamento do SUS                                  0.417895         5
# Fragilidades relacionadas ao modelo de gestão d...       0.405263         6
# Grau de independência de cada serviço de saúde ...       0.089474         7
# Fragilidades relacionadas ao modelo de atenção ...       0.083158         8
# Administração Central insensível às demandas da...       0.076842         9
# Resistência das unidades próprias de Saúde à ce...       0.024211        10
# Ausência de interlocução do DGRH com a DEAS em ...      -0.027368        11
# Perda de conhecimentos intangíveis com os proce...      -0.049474        12
# Burocratização exacerbada de processos administ...      -0.220000        13
# Demandas excessivas dos órgãos de fiscalização ...      -0.247368        14
# Impacto dos processos de judicialização da Saúde        -0.271579        15
# Sistemas informatizados da universidade e ausên...      -0.305263        16
# Ponto eletrônico pode gerar processos trabalhis...      -0.327368        17
# Readequações necessárias para o cumprimento da ...      -0.363158        18
# CNPJ / CNES único                                       -0.421053        19
# Distorções existentes nos serviços de saúde cau...      -0.586316        20
# --------------------------------------------------------------------------------
# Avaliador 11:
#                                                     Fluxo Líquido  Rank D11
# Subfinanciamento do SUS                                  0.507368         1
# Instabilidade do financiamento devido às mudanç...       0.360000         2
# Instabilidade e inadequação dos recursos financ...       0.360000         3
# Fragilidades relacionadas ao modelo de atenção ...       0.270526         4
# Grau de independência de cada serviço de saúde ...       0.232632         5
# Resistência das unidades próprias de Saúde à ce...       0.190526         6
# Fragilidade de políticas específicas do Estado ...       0.067368         7
# Insuficiência do financiamento das unidades con...       0.023158         8
# CNPJ / CNES único                                       -0.041053         9
# Administração Central insensível às demandas da...      -0.054737        10
# Demandas excessivas dos órgãos de fiscalização ...      -0.066316        11
# Burocratização exacerbada de processos administ...      -0.083158        12
# Distorções existentes nos serviços de saúde cau...      -0.088421        13
# Impacto dos processos de judicialização da Saúde        -0.104211        14
# Fragilidades relacionadas ao modelo de gestão d...      -0.227368        15
# Perda de conhecimentos intangíveis com os proce...      -0.249474        16
# Readequações necessárias para o cumprimento da ...      -0.269474        17
# Ausência de interlocução do DGRH com a DEAS em ...      -0.269474        18
# Sistemas informatizados da universidade e ausên...      -0.274737        19
# Ponto eletrônico pode gerar processos trabalhis...      -0.283158        20
# --------------------------------------------------------------------------------

# %%
# generating the tables for each decision-maker (threats)
ordem_ameaça_a1 = ordenamento(1, ameaça_a1, fl_a1)
ordem_ameaça_a2 = ordenamento(2, ameaça_a2, fl_a2)
ordem_ameaça_a3 = ordenamento(3, ameaça_a3, fl_a3)
ordem_ameaça_a4 = ordenamento(4, ameaça_a4, fl_a4)
ordem_ameaça_a5 = ordenamento(5, ameaça_a5, fl_a5)
ordem_ameaça_a6 = ordenamento(6, ameaça_a6, fl_a6)
ordem_ameaça_a7 = ordenamento(7, ameaça_a7, fl_a7)
ordem_ameaça_a8 = ordenamento(8, ameaça_a8, fl_a8)
ordem_ameaça_a9 = ordenamento(9, ameaça_a9, fl_a9)
ordem_ameaça_a10 = ordenamento(10, ameaça_a10, fl_a10)
ordem_ameaça_a11 = ordenamento(11, ameaça_a11, fl_a11)

# creating a dataframe with the rankings of all the decision-makers:
ameaça = pd.concat([ordem_ameaça_a1, ordem_ameaça_a2, ordem_ameaça_a3, ordem_ameaça_a4, ordem_ameaça_a5, ordem_ameaça_a6, ordem_ameaça_a7, ordem_ameaça_a8, ordem_ameaça_a9, ordem_ameaça_a10, ordem_ameaça_a11], axis=1)
ameaça = ameaça.drop(['Fluxo Líquido'], axis=1)
ameaça
# Out:
#                                                     Rank D1  Rank D2  Rank D3  \
# Distorções existentes nos serviços de saúde cau...        1       15       19
# Subfinanciamento do SUS                                   2       19        6
# Administração Central insensível às demandas da...        3        6        9
# Grau de independência de cada serviço de saúde ...        4        2        2
# Instabilidade e inadequação dos recursos financ...        5        8        5
# Ausência de interlocução do DGRH com a DEAS em ...        6        3       18
# Sistemas informatizados da universidade e ausên...        7        7       11
# Resistência das unidades próprias de Saúde à ce...        8        1        1
# Fragilidades relacionadas ao modelo de gestão d...        9       16       10
# Instabilidade do financiamento devido às mudanç...       10       12        4
# Ponto eletrônico pode gerar processos trabalhis...       11       13       14
# Readequações necessárias para o cumprimento da ...       12       10       12
# Insuficiência do financiamento das unidades con...       13        9        7
# Fragilidade de políticas específicas do Estado ...       14        5        8
# Demandas excessivas dos órgãos de fiscalização ...       15       18       16
# Fragilidades relacionadas ao modelo de atenção ...       16       17        3
# Burocratização exacerbada de processos administ...       17       14       13
# Impacto dos processos de judicialização da Saúde         18       20       15
# Perda de conhecimentos intangíveis com os proce...       19        4       20
# CNPJ / CNES único                                        20       11       17
#
#                                                     Rank D4  Rank D5  Rank D6  \
# Distorções existentes nos serviços de saúde cau...       18       19        8
# Subfinanciamento do SUS                                  10        7       12
# Administração Central insensível às demandas da...        2       15       15
# Grau de independência de cada serviço de saúde ...        7        1        6
# Instabilidade e inadequação dos recursos financ...       11        8       16
# Ausência de interlocução do DGRH com a DEAS em ...       17       13        4
# Sistemas informatizados da universidade e ausên...       15       16        1
# Resistência das unidades próprias de Saúde à ce...        5        4       10
# Fragilidades relacionadas ao modelo de gestão d...        1        3       11
# Instabilidade do financiamento devido às mudanç...        3       10       18
# Ponto eletrônico pode gerar processos trabalhis...       19        2       20
# Readequações necessárias para o cumprimento da ...       14       11       14
# Insuficiência do financiamento das unidades con...        9        9        5
# Fragilidade de políticas específicas do Estado ...        8       17       17
# Demandas excessivas dos órgãos de fiscalização ...       13       12        3
# Fragilidades relacionadas ao modelo de atenção ...        4        5       19
# Burocratização exacerbada de processos administ...       12        6        9
# Impacto dos processos de judicialização da Saúde         16       14       13
# Perda de conhecimentos intangíveis com os proce...       20       20        2
# CNPJ / CNES único                                         6       18        7
#
#                                                     Rank D7  Rank D8  Rank D9  \
# Distorções existentes nos serviços de saúde cau...       20       19       20
# Subfinanciamento do SUS                                  13        2       11
# Administração Central insensível às demandas da...       10        9        3
# Grau de independência de cada serviço de saúde ...        4       13       10
# Instabilidade e inadequação dos recursos financ...        5        4        8
# Ausência de interlocução do DGRH com a DEAS em ...        2       18       16
# Sistemas informatizados da universidade e ausên...        6       12       19
# Resistência das unidades próprias de Saúde à ce...       11       11        2
# Fragilidades relacionadas ao modelo de gestão d...       15        6        1
# Instabilidade do financiamento devido às mudanç...        3        3        6
# Ponto eletrônico pode gerar processos trabalhis...       17       15       14
# Readequações necessárias para o cumprimento da ...       18       20       15
# Insuficiência do financiamento das unidades con...        1        1        9
# Fragilidade de políticas específicas do Estado ...       12       17        4
# Demandas excessivas dos órgãos de fiscalização ...        8        8       18
# Fragilidades relacionadas ao modelo de atenção ...        9        7        5
# Burocratização exacerbada de processos administ...       14       16       12
# Impacto dos processos de judicialização da Saúde          7        5        7
# Perda de conhecimentos intangíveis com os proce...       16       14       13
# CNPJ / CNES único                                        19       10       17
#
#                                                     Rank D10  Rank D11
# Distorções existentes nos serviços de saúde cau...        20        13
# Subfinanciamento do SUS                                    5         1
# Administração Central insensível às demandas da...         9        10
# Grau de independência de cada serviço de saúde ...         7         5
# Instabilidade e inadequação dos recursos financ...         3         3
# Ausência de interlocução do DGRH com a DEAS em ...        11        18
# Sistemas informatizados da universidade e ausên...        16        19
# Resistência das unidades próprias de Saúde à ce...        10         6
# Fragilidades relacionadas ao modelo de gestão d...         6        15
# Instabilidade do financiamento devido às mudanç...         2         2
# Ponto eletrônico pode gerar processos trabalhis...        17        20
# Readequações necessárias para o cumprimento da ...        18        17
# Insuficiência do financiamento das unidades con...         4         8
# Fragilidade de políticas específicas do Estado ...         1         7
# Demandas excessivas dos órgãos de fiscalização ...        14        11
# Fragilidades relacionadas ao modelo de atenção ...         8         4
# Burocratização exacerbada de processos administ...        13        12
# Impacto dos processos de judicialização da Saúde          15        14
# Perda de conhecimentos intangíveis com os proce...        12        16
# CNPJ / CNES único                                         19         9

# %% [markdown]
# ## Group Decision (Borda)

# %%
# creating a scale for the border
borda_ameaça = {}
for i in range(0, len(ameaça)):
  borda_ameaça.update({i+1: (len(ameaça)-i)})

peso_dirigente = 1.2
borda_ameaça_dirig = {}
for i in range(0, len(ameaça)):
  borda_ameaça_dirig.update({i+1: (len(ameaça)-i)*peso_dirigente})

# replacing the sort values with the Edge scale value
# Ex: (1,2,3) will become (3,2,1)
for i in ameaça.columns:
  if i == ameaça.columns[0]: # if the decision-maker is the manager (greater weight)
    ameaça[i] = ameaça[i].map(borda_ameaça_dirig)
  else:
    ameaça[i] = ameaça[i].map(borda_ameaça)

# adding up the values of each alternative
ameaça['Valor'] = ameaça.sum(axis=1)
# threat

ameaça_final = pd.DataFrame(ameaça['Valor'])
ameaça_final = ameaça_final.sort_values(by='Valor', ascending=False)

ord = []
for i in range(0, len(ameaça_final)):
  ord.append(f'{i+1}°')

ameaça_final['Ordem Final (Borda)'] = ord
ameaça_final
# Out:
#                                                     Valor Ordem Final (Borda)
# Grau de independência de cada serviço de saúde ...  173.4                  1°
# Resistência das unidades próprias de Saúde à ce...  164.6                  2°
# Instabilidade do financiamento devido às mudanç...  160.2                  3°
# Instabilidade e inadequação dos recursos financ...  158.2                  4°
# Insuficiência do financiamento das unidades con...  157.6                  5°
# Subfinanciamento do SUS                             146.8                  6°
# Administração Central insensível às demandas da...  143.6                  7°
# Fragilidades relacionadas ao modelo de gestão d...  140.4                  8°
# Fragilidades relacionadas ao modelo de atenção ...  135.0                  9°
# Fragilidade de políticas específicas do Estado ...  122.4                 10°
# Ausência de interlocução do DGRH com a DEAS em ...  108.0                 11°
# Sistemas informatizados da universidade e ausên...  104.8                 12°
# Demandas excessivas dos órgãos de fiscalização ...   96.2                 13°
# Burocratização exacerbada de processos administ...   93.8                 14°
# Impacto dos processos de judicialização da Saúde     87.6                 15°
# CNPJ / CNES único                                    78.2                 16°
# Perda de conhecimentos intangíveis com os proce...   75.4                 17°
# Readequações necessárias para o cumprimento da ...   71.8                 18°
# Ponto eletrônico pode gerar processos trabalhis...   71.0                 19°
# Distorções existentes nos serviços de saúde cau...   63.0                 20°

# %% [markdown]
# ## Group Decision (Condorcet):

# %%
ordem_ameaça_a1 = ordenamento(1, ameaça_a1, fl_a1)
ordem_ameaça_a2 = ordenamento(2, ameaça_a2, fl_a2)
ordem_ameaça_a3 = ordenamento(3, ameaça_a3, fl_a3)
ordem_ameaça_a4 = ordenamento(4, ameaça_a4, fl_a4)
ordem_ameaça_a5 = ordenamento(5, ameaça_a5, fl_a5)
ordem_ameaça_a6 = ordenamento(6, ameaça_a6, fl_a6)
ordem_ameaça_a7 = ordenamento(7, ameaça_a7, fl_a7)
ordem_ameaça_a8 = ordenamento(8, ameaça_a8, fl_a8)
ordem_ameaça_a9 = ordenamento(9, ameaça_a9, fl_a9)
ordem_ameaça_a10 = ordenamento(10, ameaça_a10, fl_a10)
ordem_ameaça_a11 = ordenamento(11, ameaça_a11, fl_a11)

candidatos = ordem_ameaça_a1.index.values
candidatos = list(candidatos)

lista_ameaça = [ordem_ameaça_a1, ordem_ameaça_a2, ordem_ameaça_a3, ordem_ameaça_a4, ordem_ameaça_a5, ordem_ameaça_a6, ordem_ameaça_a7, ordem_ameaça_a8, ordem_ameaça_a9, ordem_ameaça_a10, ordem_ameaça_a11]
votos = voto(lista_ameaça)

# using condorcet library functions to define sorting
evaluator = condorcet.CondorcetEvaluator(candidates=candidatos, votes=votos)
winners, rest_of_table = evaluator.get_n_winners(len(ordem_ameaça_a1))

ameaça_condorcet = pd.DataFrame(index=winners)

ord = []
for i in range(0, len(ameaça_condorcet)):
  ord.append(f'{i+1}°')
ameaça_condorcet['Ordem Final (Condorcet)'] = ord

ameaça_condorcet
# Out:
# Empty DataFrame
# Columns: [Ordem Final (Condorcet)]
# Index: []

# %% [markdown]
# # Weak points

# %%
# Importing the problem data (weak points)

fraco_a1 = pd.read_excel('Assets\Datasets\PO_ER460 - Weak points.xlsx', sheet_name=0)
fraco_a2 = pd.read_excel('Assets\Datasets\PO_ER460 - Weak points.xlsx', sheet_name=1)
fraco_a3 = pd.read_excel('Assets\Datasets\PO_ER460 - Weak points.xlsx', sheet_name=2)
fraco_a4 = pd.read_excel('Assets\Datasets\PO_ER460 - Weak points.xlsx', sheet_name=3)
fraco_a5 = pd.read_excel('Assets\Datasets\PO_ER460 - Weak points.xlsx', sheet_name=4)
fraco_a6 = pd.read_excel('Assets\Datasets\PO_ER460 - Weak points.xlsx', sheet_name=5)
fraco_a7 = pd.read_excel('Assets\Datasets\PO_ER460 - Weak points.xlsx', sheet_name=6)
fraco_a8 = pd.read_excel('Assets\Datasets\PO_ER460 - Weak points.xlsx', sheet_name=7)
fraco_a9 = pd.read_excel('Assets\Datasets\PO_ER460 - Weak points.xlsx', sheet_name=8)
fraco_a10 = pd.read_excel('Assets\Datasets\PO_ER460 - Weak points.xlsx', sheet_name=9)
fraco_a11 = pd.read_excel('Assets\Datasets\PO_ER460 - Weak points.xlsx', sheet_name=10)

# %%
# making the alternatives like indexes
def indice(df):
  df = df.set_index('Alternativas/Critérios')
  df.index.names = [None]
  return df

fraco_a1 = indice(fraco_a1)
fraco_a2 = indice(fraco_a2)
fraco_a3 = indice(fraco_a3)
fraco_a4 = indice(fraco_a4)
fraco_a5 = indice(fraco_a5)
fraco_a6 = indice(fraco_a6)
fraco_a7 = indice(fraco_a7)
fraco_a8 = indice(fraco_a8)
fraco_a9 = indice(fraco_a9)
fraco_a10 = indice(fraco_a10)
fraco_a11 = indice(fraco_a11)

# %%
# creating a numerical scale and passing it to df
def escala(df):
  dic = {'Muito Alto':5, 'Alto':4 , 'Médio':3, 'Baixo':2, 'Muito Baixo':1}
  df['Custo'] = df['Custo'].map(dic)
  df['Retorno'] = df['Retorno'].map(dic)
  df['Missão'] = df['Missão'].map(dic)
  df['Visão'] = df['Visão'].map(dic)
  return df

fraco_a1 = escala(fraco_a1)
fraco_a2 = escala(fraco_a2)
fraco_a3 = escala(fraco_a3)
fraco_a4 = escala(fraco_a4)
fraco_a5 = escala(fraco_a5)
fraco_a6 = escala(fraco_a6)
fraco_a7 = escala(fraco_a7)
fraco_a8 = escala(fraco_a8)
fraco_a9 = escala(fraco_a9)
fraco_a10 = escala(fraco_a10)
fraco_a11 = escala(fraco_a11)

# %%
# creating a numerical scale and passing it to df
def M_fraco(df, w):
  m_pot_ame = f_pref(df, 'Pot. Ameaças', 'max', 'linear', q=1, p=4)
  m_dif_oport = f_pref(df, 'Dif. Oport.', 'max', 'linear', q=1, p=4)
  m_custo = f_pref(df, 'Custo', 'min')
  m_ret = f_pref(df, 'Retorno', 'max')
  m_missao = f_pref(df, 'Missão', 'max')
  m_visao = f_pref(df, 'Visão', 'max')

  matrizes = [m_pot_ame, m_dif_oport, m_custo, m_ret, m_missao, m_visao]

  M = 0
  for i in range(0, len(matrizes)):
    M = M + w[i]*matrizes[i]

  return M

# vector of weights
w_fraco = [0.09, 0.06, 0.12, 0.10, 0.23, 0.40]

# calculating the preference matrices for each decision-maker (weaknesses):
M_a1 = M_fraco(fraco_a1, w_fraco)
M_a2 = M_fraco(fraco_a2, w_fraco)
M_a3 = M_fraco(fraco_a3, w_fraco)
M_a4 = M_fraco(fraco_a4, w_fraco)
M_a5 = M_fraco(fraco_a5, w_fraco)
M_a6 = M_fraco(fraco_a6, w_fraco)
M_a7 = M_fraco(fraco_a7, w_fraco)
M_a8 = M_fraco(fraco_a8, w_fraco)
M_a9 = M_fraco(fraco_a9, w_fraco)
M_a10 = M_fraco(fraco_a10, w_fraco)
M_a11 = M_fraco(fraco_a11, w_fraco)
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_16368\2012082991.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   d = df[criterio][i] - df[criterio][j]
# C:\Users\lucas\AppData\Local\Temp\ipykernel_16368\2012082991.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   d = df[criterio][j] - df[criterio][i]

# %%
# calculating the net flow
def fl_fraco(M):
  fl = fluxo_liq(fluxo_pos(M), fluxo_neg(M))
  return fl

fl_a1 = fl_fraco(M_a1)
fl_a2 = fl_fraco(M_a2)
fl_a3 = fl_fraco(M_a3)
fl_a4 = fl_fraco(M_a4)
fl_a5 = fl_fraco(M_a5)
fl_a6 = fl_fraco(M_a6)
fl_a7 = fl_fraco(M_a7)
fl_a8 = fl_fraco(M_a8)
fl_a9 = fl_fraco(M_a9)
fl_a10 = fl_fraco(M_a10)
fl_a11 = fl_fraco(M_a11)

# %%
# function for sorting
def ordenamento(decisor, df, fl):
  # generating a dictionary for ranking
  rank = {}
  for i in range(0, len(df)):
    rank.update({df.index.values[i] : fl[i]})

  tabela = pd.DataFrame(pd.Series(rank), columns=['Fluxo Líquido'])

  tabela = tabela.sort_values(by='Fluxo Líquido', ascending=False)

  ord = []
  for i in range(0, len(df)):
    ord.append(i+1)

  tabela[f'Rank D{decisor}'] = ord

  return tabela

# %%
print('Avaliador 1:')
print(ordenamento(1, fraco_a1, fl_a1))
print(80*'-')
print('Avaliador 2:')
print(ordenamento(2, fraco_a2, fl_a2))
print(80*'-')
print('Avaliador 3:')
print(ordenamento(3, fraco_a3, fl_a3))
print(80*'-')
print('Avaliador 4:')
print(ordenamento(4, fraco_a4, fl_a4))
print(80*'-')
print('Avaliador 5:')
print(ordenamento(5, fraco_a5, fl_a5))
print(80*'-')
print('Avaliador 6:')
print(ordenamento(6, fraco_a6, fl_a6))
print(80*'-')
print('Avaliador 7:')
print(ordenamento(7, fraco_a7, fl_a7))
print(80*'-')
print('Avaliador 8:')
print(ordenamento(8, fraco_a8, fl_a8))
print(80*'-')
print('Avaliador 9:')
print(ordenamento(9, fraco_a9, fl_a9))
print(80*'-')
print('Avaliador 10:')
print(ordenamento(10, fraco_a10, fl_a10))
print(80*'-')
print('Avaliador 11:')
print(ordenamento(11, fraco_a11, fl_a11))
print(80*'-')
# Out:
# Avaliador 1:
#                                                     Fluxo Líquido  Rank D1
# Efetivação do papel institucional (não reconhec...       0.513333        1
# Área física inadequada                                   0.460000        2
# Fragilidade da equipe nos conhecimentos “relaci...       0.360833        3
# Falta de autonomia financeira interna                    0.348333        4
# Predominância de ações emergenciais em detrimen...       0.340833        5
# Ausência de ferramentas gerenciais de diagnósti...       0.070000        6
# Falta de integração dos processos de trabalho (...      -0.010000        7
# Equipe reduzida                                         -0.042500        8
# Ausência de integração entre pesquisa, ensino e...      -0.163333        9
# O Conselho Executivo não participa das discussõ...      -0.345833       10
# Falta organização e diretrizes para captação de...      -0.475833       11
# Inexistência da centralização de compras na Áre...      -0.504167       12
# A gestão vinculada às fundações intervenientes          -0.551667       13
# --------------------------------------------------------------------------------
# Avaliador 2:
#                                                     Fluxo Líquido  Rank D2
# Efetivação do papel institucional (não reconhec...       0.565833        1
# O Conselho Executivo não participa das discussõ...       0.419167        2
# Ausência de ferramentas gerenciais de diagnósti...       0.351667        3
# Inexistência da centralização de compras na Áre...       0.285833        4
# Falta de autonomia financeira interna                    0.005000        5
# Falta de integração dos processos de trabalho (...      -0.185000        6
# Equipe reduzida                                         -0.190833        7
# Ausência de integração entre pesquisa, ensino e...      -0.190833        8
# A gestão vinculada às fundações intervenientes          -0.190833        9
# Fragilidade da equipe nos conhecimentos “relaci...      -0.197500       10
# Predominância de ações emergenciais em detrimen...      -0.215833       11
# Falta organização e diretrizes para captação de...      -0.223333       12
# Área física inadequada                                  -0.233333       13
# --------------------------------------------------------------------------------
# Avaliador 3:
#                                                     Fluxo Líquido  Rank D3
# Falta de integração dos processos de trabalho (...       0.790833        1
# Efetivação do papel institucional (não reconhec...       0.729167        2
# O Conselho Executivo não participa das discussõ...       0.531667        3
# Ausência de integração entre pesquisa, ensino e...       0.304167        4
# Ausência de ferramentas gerenciais de diagnósti...       0.132500        5
# Fragilidade da equipe nos conhecimentos “relaci...       0.035833        6
# Predominância de ações emergenciais em detrimen...       0.031667        7
# Falta organização e diretrizes para captação de...       0.021667        8
# A gestão vinculada às fundações intervenientes          -0.203333        9
# Equipe reduzida                                         -0.327500       10
# Falta de autonomia financeira interna                   -0.616667       11
# Área física inadequada                                  -0.641667       12
# Inexistência da centralização de compras na Áre...      -0.788333       13
# --------------------------------------------------------------------------------
# Avaliador 4:
#                                                     Fluxo Líquido  Rank D4
# O Conselho Executivo não participa das discussõ...       0.522500        1
# Equipe reduzida                                          0.375000        2
# Falta de autonomia financeira interna                    0.345000        3
# Predominância de ações emergenciais em detrimen...       0.190000        4
# Falta de integração dos processos de trabalho (...       0.138333        5
# Ausência de ferramentas gerenciais de diagnósti...       0.065833        6
# Falta organização e diretrizes para captação de...      -0.029167        7
# Fragilidade da equipe nos conhecimentos “relaci...      -0.081667        8
# A gestão vinculada às fundações intervenientes          -0.162500        9
# Ausência de integração entre pesquisa, ensino e...      -0.162500       10
# Efetivação do papel institucional (não reconhec...      -0.222500       11
# Inexistência da centralização de compras na Áre...      -0.355833       12
# Área física inadequada                                  -0.622500       13
# --------------------------------------------------------------------------------
# Avaliador 5:
#                                                     Fluxo Líquido  Rank D5
# Equipe reduzida                                          0.450000        1
# Falta organização e diretrizes para captação de...       0.404167        2
# Falta de autonomia financeira interna                    0.301667        3
# Efetivação do papel institucional (não reconhec...       0.282500        4
# Predominância de ações emergenciais em detrimen...       0.181667        5
# Ausência de ferramentas gerenciais de diagnósti...       0.130833        6
# A gestão vinculada às fundações intervenientes           0.010000        7
# Fragilidade da equipe nos conhecimentos “relaci...      -0.027500        8
# O Conselho Executivo não participa das discussõ...      -0.225833        9
# Ausência de integração entre pesquisa, ensino e...      -0.229167       10
# Área física inadequada                                  -0.370833       11
# Inexistência da centralização de compras na Áre...      -0.427500       12
# Falta de integração dos processos de trabalho (...      -0.480000       13
# --------------------------------------------------------------------------------
# Avaliador 6:
#                                                     Fluxo Líquido  Rank D6
# Predominância de ações emergenciais em detrimen...       0.538333        1
# Efetivação do papel institucional (não reconhec...       0.486667        2
# Falta de integração dos processos de trabalho (...       0.456667        3
# O Conselho Executivo não participa das discussõ...       0.456667        4
# Área física inadequada                                   0.116667        5
# Fragilidade da equipe nos conhecimentos “relaci...       0.014167        6
# Ausência de integração entre pesquisa, ensino e...      -0.053333        7
# Ausência de ferramentas gerenciais de diagnósti...      -0.060000        8
# Equipe reduzida                                         -0.062500        9
# Inexistência da centralização de compras na Áre...      -0.150000       10
# Falta organização e diretrizes para captação de...      -0.391667       11
# Falta de autonomia financeira interna                   -0.675000       12
# A gestão vinculada às fundações intervenientes          -0.676667       13
# --------------------------------------------------------------------------------
# Avaliador 7:
#                                                     Fluxo Líquido  Rank D7
# Inexistência da centralização de compras na Áre...       0.460000        1
# Efetivação do papel institucional (não reconhec...       0.396667        2
# Ausência de ferramentas gerenciais de diagnósti...       0.395833        3
# Equipe reduzida                                          0.393333        4
# Falta de integração dos processos de trabalho (...       0.025000        5
# Predominância de ações emergenciais em detrimen...      -0.050833        6
# O Conselho Executivo não participa das discussõ...      -0.056667        7
# A gestão vinculada às fundações intervenientes          -0.089167        8
# Fragilidade da equipe nos conhecimentos “relaci...      -0.097500        9
# Falta de autonomia financeira interna                   -0.177500       10
# Ausência de integração entre pesquisa, ensino e...      -0.234167       11
# Falta organização e diretrizes para captação de...      -0.462500       12
# Área física inadequada                                  -0.502500       13
# --------------------------------------------------------------------------------
# Avaliador 8:
#                                                     Fluxo Líquido  Rank D8
# Ausência de ferramentas gerenciais de diagnósti...       0.620000        1
# Equipe reduzida                                          0.482500        2
# Fragilidade da equipe nos conhecimentos “relaci...       0.452500        3
# Efetivação do papel institucional (não reconhec...       0.028333        4
# Falta de integração dos processos de trabalho (...      -0.063333        5
# Predominância de ações emergenciais em detrimen...      -0.118333        6
# O Conselho Executivo não participa das discussõ...      -0.178333        7
# Inexistência da centralização de compras na Áre...      -0.178333        8
# Falta de autonomia financeira interna                   -0.184167        9
# Falta organização e diretrizes para captação de...      -0.184167       10
# Ausência de integração entre pesquisa, ensino e...      -0.215833       11
# A gestão vinculada às fundações intervenientes          -0.215833       12
# Área física inadequada                                  -0.245000       13
# --------------------------------------------------------------------------------
# Avaliador 9:
#                                                     Fluxo Líquido  Rank D9
# Falta de integração dos processos de trabalho (...       0.789167        1
# Predominância de ações emergenciais em detrimen...       0.632500        2
# Fragilidade da equipe nos conhecimentos “relaci...       0.245000        3
# O Conselho Executivo não participa das discussõ...       0.099167        4
# Ausência de integração entre pesquisa, ensino e...       0.082500        5
# Ausência de ferramentas gerenciais de diagnósti...       0.043333        6
# Falta organização e diretrizes para captação de...       0.009167        7
# A gestão vinculada às fundações intervenientes          -0.040833        8
# Efetivação do papel institucional (não reconhec...      -0.086667        9
# Inexistência da centralização de compras na Áre...      -0.137500       10
# Equipe reduzida                                         -0.414167       11
# Falta de autonomia financeira interna                   -0.595000       12
# Área física inadequada                                  -0.626667       13
# --------------------------------------------------------------------------------
# Avaliador 10:
#                                                     Fluxo Líquido  Rank D10
# Efetivação do papel institucional (não reconhec...       0.620000         1
# O Conselho Executivo não participa das discussõ...       0.612500         2
# Fragilidade da equipe nos conhecimentos “relaci...       0.203333         3
# Predominância de ações emergenciais em detrimen...       0.193333         4
# Falta de autonomia financeira interna                    0.170833         5
# A gestão vinculada às fundações intervenientes           0.148333         6
# Ausência de integração entre pesquisa, ensino e...       0.063333         7
# Área física inadequada                                   0.046667         8
# Equipe reduzida                                         -0.335833         9
# Falta de integração dos processos de trabalho (...      -0.393333        10
# Ausência de ferramentas gerenciais de diagnósti...      -0.415833        11
# Falta organização e diretrizes para captação de...      -0.425000        12
# Inexistência da centralização de compras na Áre...      -0.488333        13
# --------------------------------------------------------------------------------
# Avaliador 11:
#                                                     Fluxo Líquido  Rank D11
# Ausência de integração entre pesquisa, ensino e...       0.487500         1
# Falta de integração dos processos de trabalho (...       0.295833         2
# O Conselho Executivo não participa das discussõ...       0.195833         3
# Ausência de ferramentas gerenciais de diagnósti...       0.184167         4
# Falta organização e diretrizes para captação de...       0.083333         5
# Efetivação do papel institucional (não reconhec...       0.012500         6
# Falta de autonomia financeira interna                   -0.006667         7
# Predominância de ações emergenciais em detrimen...      -0.034167         8
# A gestão vinculada às fundações intervenientes          -0.042500         9
# Inexistência da centralização de compras na Áre...      -0.129167        10
# Equipe reduzida                                         -0.142500        11
# Fragilidade da equipe nos conhecimentos “relaci...      -0.235000        12
# Área física inadequada                                  -0.669167        13
# --------------------------------------------------------------------------------

# %%
# generating the tables for each decision-maker (weaknesses)
ordem_fraco_a1 = ordenamento(1, fraco_a1, fl_a1)
ordem_fraco_a2 = ordenamento(2, fraco_a2, fl_a2)
ordem_fraco_a3 = ordenamento(3, fraco_a3, fl_a3)
ordem_fraco_a4 = ordenamento(4, fraco_a4, fl_a4)
ordem_fraco_a5 = ordenamento(5, fraco_a5, fl_a5)
ordem_fraco_a6 = ordenamento(6, fraco_a6, fl_a6)
ordem_fraco_a7 = ordenamento(7, fraco_a7, fl_a7)
ordem_fraco_a8 = ordenamento(8, fraco_a8, fl_a8)
ordem_fraco_a9 = ordenamento(9, fraco_a9, fl_a9)
ordem_fraco_a10 = ordenamento(10, fraco_a10, fl_a10)
ordem_fraco_a11 = ordenamento(11, fraco_a11, fl_a11)

# creating a dataframe with the rankings of all the decision-makers:
pont_fracos = pd.concat([ordem_fraco_a1, ordem_fraco_a2, ordem_fraco_a3, ordem_fraco_a4, ordem_fraco_a5, ordem_fraco_a6, ordem_fraco_a7, ordem_fraco_a8, ordem_fraco_a9, ordem_fraco_a10, ordem_fraco_a11], axis=1)
pont_fracos = pont_fracos.drop(['Fluxo Líquido'], axis=1)
pont_fracos
# Out:
#                                                     Rank D1  Rank D2  Rank D3  \
# Efetivação do papel institucional (não reconhec...        1        1        2
# Área física inadequada                                    2       13       12
# Fragilidade da equipe nos conhecimentos “relaci...        3       10        6
# Falta de autonomia financeira interna                     4        5       11
# Predominância de ações emergenciais em detrimen...        5       11        7
# Ausência de ferramentas gerenciais de diagnósti...        6        3        5
# Falta de integração dos processos de trabalho (...        7        6        1
# Equipe reduzida                                           8        7       10
# Ausência de integração entre pesquisa, ensino e...        9        8        4
# O Conselho Executivo não participa das discussõ...       10        2        3
# Falta organização e diretrizes para captação de...       11       12        8
# Inexistência da centralização de compras na Áre...       12        4       13
# A gestão vinculada às fundações intervenientes           13        9        9
#
#                                                     Rank D4  Rank D5  Rank D6  \
# Efetivação do papel institucional (não reconhec...       11        4        2
# Área física inadequada                                   13       11        5
# Fragilidade da equipe nos conhecimentos “relaci...        8        8        6
# Falta de autonomia financeira interna                     3        3       12
# Predominância de ações emergenciais em detrimen...        4        5        1
# Ausência de ferramentas gerenciais de diagnósti...        6        6        8
# Falta de integração dos processos de trabalho (...        5       13        3
# Equipe reduzida                                           2        1        9
# Ausência de integração entre pesquisa, ensino e...       10       10        7
# O Conselho Executivo não participa das discussõ...        1        9        4
# Falta organização e diretrizes para captação de...        7        2       11
# Inexistência da centralização de compras na Áre...       12       12       10
# A gestão vinculada às fundações intervenientes            9        7       13
#
#                                                     Rank D7  Rank D8  Rank D9  \
# Efetivação do papel institucional (não reconhec...        2        4        9
# Área física inadequada                                   13       13       13
# Fragilidade da equipe nos conhecimentos “relaci...        9        3        3
# Falta de autonomia financeira interna                    10        9       12
# Predominância de ações emergenciais em detrimen...        6        6        2
# Ausência de ferramentas gerenciais de diagnósti...        3        1        6
# Falta de integração dos processos de trabalho (...        5        5        1
# Equipe reduzida                                           4        2       11
# Ausência de integração entre pesquisa, ensino e...       11       11        5
# O Conselho Executivo não participa das discussõ...        7        7        4
# Falta organização e diretrizes para captação de...       12       10        7
# Inexistência da centralização de compras na Áre...        1        8       10
# A gestão vinculada às fundações intervenientes            8       12        8
#
#                                                     Rank D10  Rank D11
# Efetivação do papel institucional (não reconhec...         1         6
# Área física inadequada                                     8        13
# Fragilidade da equipe nos conhecimentos “relaci...         3        12
# Falta de autonomia financeira interna                      5         7
# Predominância de ações emergenciais em detrimen...         4         8
# Ausência de ferramentas gerenciais de diagnósti...        11         4
# Falta de integração dos processos de trabalho (...        10         2
# Equipe reduzida                                            9        11
# Ausência de integração entre pesquisa, ensino e...         7         1
# O Conselho Executivo não participa das discussõ...         2         3
# Falta organização e diretrizes para captação de...        12         5
# Inexistência da centralização de compras na Áre...        13        10
# A gestão vinculada às fundações intervenientes             6         9

# %% [markdown]
# ## Group Decision (Borda)

# %%
# creating a scale for the border
borda_fraco = {}
for i in range(0, len(pont_fracos)):
  borda_fraco.update({i+1: (len(pont_fracos)-i)})

peso_dirigente = 1.2
borda_fraco_dirig = {}
for i in range(0, len(pont_fracos)):
  borda_fraco_dirig.update({i+1: (len(pont_fracos)-i)*peso_dirigente})

# replacing the sort values with the Edge scale value
# Ex: (1,2,3) will become (3,2,1)
for i in pont_fracos.columns:
  if i == pont_fracos.columns[0]: # if the decision-maker is the manager (greater weight)
    pont_fracos[i] = pont_fracos[i].map(borda_fraco_dirig)
  else:
    pont_fracos[i] = pont_fracos[i].map(borda_fraco)

# adding up the values of each alternative
pont_fracos['Valor'] = pont_fracos.sum(axis=1)

pont_fracos_final = pd.DataFrame(pont_fracos['Valor'])
pont_fracos_final = pont_fracos_final.sort_values(by='Valor', ascending=False)

ord = []
for i in range(0, len(pont_fracos_final)):
  ord.append(f'{i+1}°')

pont_fracos_final['Ordem Final (Borda)'] = ord
pont_fracos_final
# Out:
#                                                     Valor Ordem Final (Borda)
# Efetivação do papel institucional (não reconhec...  113.6                  1°
# O Conselho Executivo não participa das discussõ...  102.8                  2°
# Falta de integração dos processos de trabalho (...   97.4                  3°
# Predominância de ações emergenciais em detrimen...   96.8                  4°
# Ausência de ferramentas gerenciais de diagnósti...   96.6                  5°
# Fragilidade da equipe nos conhecimentos “relaci...   85.2                  6°
# Equipe reduzida                                      81.2                  7°
# Falta de autonomia financeira interna                75.0                  8°
# Ausência de integração entre pesquisa, ensino e...   72.0                  9°
# Falta organização e diretrizes para captação de...   57.6                 10°
# A gestão vinculada às fundações intervenientes       51.2                 11°
# Inexistência da centralização de compras na Áre...   49.4                 12°
# Área física inadequada                               40.4                 13°

# %% [markdown]
# ## Group Decision (Condorcet):

# %%
ordem_fraco_a1 = ordenamento(1, fraco_a1, fl_a1)
ordem_fraco_a2 = ordenamento(2, fraco_a2, fl_a2)
ordem_fraco_a3 = ordenamento(3, fraco_a3, fl_a3)
ordem_fraco_a4 = ordenamento(4, fraco_a4, fl_a4)
ordem_fraco_a5 = ordenamento(5, fraco_a5, fl_a5)
ordem_fraco_a6 = ordenamento(6, fraco_a6, fl_a6)
ordem_fraco_a7 = ordenamento(7, fraco_a7, fl_a7)
ordem_fraco_a8 = ordenamento(8, fraco_a8, fl_a8)
ordem_fraco_a9 = ordenamento(9, fraco_a9, fl_a9)
ordem_fraco_a10 = ordenamento(10, fraco_a10, fl_a10)
ordem_fraco_a11 = ordenamento(11, fraco_a11, fl_a11)

candidatos = ordem_fraco_a1.index.values
candidatos = list(candidatos)

lista_fraco = [ordem_fraco_a1, ordem_fraco_a2, ordem_fraco_a3, ordem_fraco_a4, ordem_fraco_a5, ordem_fraco_a6, ordem_fraco_a7, ordem_fraco_a8, ordem_fraco_a9, ordem_fraco_a10, ordem_fraco_a11]
votos = voto(lista_fraco)

# using condorcet library functions to define sorting
evaluator = condorcet.CondorcetEvaluator(candidates=candidatos, votes=votos)
winners, rest_of_table = evaluator.get_n_winners(len(ordem_ameaça_a1))

fraco_condorcet = pd.DataFrame(index=winners)

ord = []
for i in range(0, len(fraco_condorcet)):
  ord.append(f'{i+1}°')
fraco_condorcet['Ordem Final (Condorcet)'] = ord

fraco_condorcet
# Out:
#                                                    Ordem Final (Condorcet)
# Efetivação do papel institucional (não reconhec...                      1°
# Falta de integração dos processos de trabalho (...                      2°
# Predominância de ações emergenciais em detrimen...                      3°
# O Conselho Executivo não participa das discussõ...                      4°
# Ausência de ferramentas gerenciais de diagnósti...                      5°
# Equipe reduzida                                                         6°
# Fragilidade da equipe nos conhecimentos “relaci...                      7°
# Falta de autonomia financeira interna                                   8°
# Ausência de integração entre pesquisa, ensino e...                      9°
# Falta organização e diretrizes para captação de...                     10°
# A gestão vinculada às fundações intervenientes                         11°
# Inexistência da centralização de compras na Áre...                     12°
# Área física inadequada                                                 13°

# %%
# Importing the problem data (strengths)

forte_a1 = pd.read_excel('Assets\Datasets\PO_ER460 - Strengths.xlsx', sheet_name=0)
forte_a2 = pd.read_excel('Assets\Datasets\PO_ER460 - Strengths.xlsx', sheet_name=1)
forte_a3 = pd.read_excel('Assets\Datasets\PO_ER460 - Strengths.xlsx', sheet_name=2)
forte_a4 = pd.read_excel('Assets\Datasets\PO_ER460 - Strengths.xlsx', sheet_name=3)
forte_a5 = pd.read_excel('Assets\Datasets\PO_ER460 - Strengths.xlsx', sheet_name=4)
forte_a6 = pd.read_excel('Assets\Datasets\PO_ER460 - Strengths.xlsx', sheet_name=5)
forte_a7 = pd.read_excel('Assets\Datasets\PO_ER460 - Strengths.xlsx', sheet_name=6)
forte_a8 = pd.read_excel('Assets\Datasets\PO_ER460 - Strengths.xlsx', sheet_name=7)
forte_a9 = pd.read_excel('Assets\Datasets\PO_ER460 - Strengths.xlsx', sheet_name=8)
forte_a10 = pd.read_excel('Assets\Datasets\PO_ER460 - Strengths.xlsx', sheet_name=9)
forte_a11 = pd.read_excel('Assets\Datasets\PO_ER460 - Strengths.xlsx', sheet_name=10)

# %%
# making the alternatives like indexes
def indice(df):
  df = df.set_index('Alternativas/Critérios')
  df.index.names = [None]
  return df

forte_a1 = indice(forte_a1)
forte_a2 = indice(forte_a2)
forte_a3 = indice(forte_a3)
forte_a4 = indice(forte_a4)
forte_a5 = indice(forte_a5)
forte_a6 = indice(forte_a6)
forte_a7 = indice(forte_a7)
forte_a8 = indice(forte_a8)
forte_a9 = indice(forte_a9)
forte_a10 = indice(forte_a10)
forte_a11 = indice(forte_a11)

# %%
# creating a numerical scale and passing it to df
def escala(df):
  dic = {'Muito Alto':5, 'Alto':4 , 'Médio':3, 'Baixo':2, 'Muito Baixo':1}
  df['Missão'] = df['Missão'].map(dic)
  df['Visão'] = df['Visão'].map(dic)
  return df

forte_a1 = escala(forte_a1)
forte_a2 = escala(forte_a2)
forte_a3 = escala(forte_a3)
forte_a4 = escala(forte_a4)
forte_a5 = escala(forte_a5)
forte_a6 = escala(forte_a6)
forte_a7 = escala(forte_a7)
forte_a8 = escala(forte_a8)
forte_a9 = escala(forte_a9)
forte_a10 = escala(forte_a10)
forte_a11 = escala(forte_a11)

# %%
# creating function to calculate preference matrix M
def M_forte(df, w):
  m_pot_oport = f_pref(df, 'Pot. Oport', 'max', 'linear', q=1, p=4)
  m_neut_ame = f_pref(df, 'Neut. Ameaça', 'max', 'linear', q=1, p=4)
  m_missao = f_pref(df, 'Missão', 'max')
  m_visao = f_pref(df, 'Visão', 'max')

  matrizes = [m_pot_oport, m_neut_ame, m_missao, m_visao]

  M = 0
  for i in range(0, len(matrizes)):
    M = M + w[i]*matrizes[i]

  return M

# vector of weights
w_forte = [0.10, 0.17, 0.25, 0.48]

# calculation of preference matrices for each decision-maker (strengths):
M_a1 = M_forte(forte_a1, w_forte)
M_a2 = M_forte(forte_a2, w_forte)
M_a3 = M_forte(forte_a3, w_forte)
M_a4 = M_forte(forte_a4, w_forte)
M_a5 = M_forte(forte_a5, w_forte)
M_a6 = M_forte(forte_a6, w_forte)
M_a7 = M_forte(forte_a7, w_forte)
M_a8 = M_forte(forte_a8, w_forte)
M_a9 = M_forte(forte_a9, w_forte)
M_a10 = M_forte(forte_a10, w_forte)
M_a11 = M_forte(forte_a11, w_forte)
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_16368\2012082991.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   d = df[criterio][i] - df[criterio][j]

# %%
# calculating the net flow
def fl_forte(M):
  fl = fluxo_liq(fluxo_pos(M), fluxo_neg(M))
  return fl

fl_a1 = fl_forte(M_a1)
fl_a2 = fl_forte(M_a2)
fl_a3 = fl_forte(M_a3)
fl_a4 = fl_forte(M_a4)
fl_a5 = fl_forte(M_a5)
fl_a6 = fl_forte(M_a6)
fl_a7 = fl_forte(M_a7)
fl_a8 = fl_forte(M_a8)
fl_a9 = fl_forte(M_a9)
fl_a10 = fl_forte(M_a10)
fl_a11 = fl_forte(M_a11)

# %%
# function for sorting
def ordenamento(decisor, df, fl):
  # generating a dictionary for ranking
  rank = {}
  for i in range(0, len(df)):
    rank.update({df.index.values[i] : fl[i]})

  tabela = pd.DataFrame(pd.Series(rank), columns=['Fluxo Líquido'])

  tabela = tabela.sort_values(by='Fluxo Líquido', ascending=False)

  ord = []
  for i in range(0, len(df)):
    ord.append(i+1)

  tabela[f'Rank D{decisor}'] = ord

  return tabela

# %%
print('Avaliador 1:')
print(ordenamento(1, forte_a1, fl_a1))
print(80*'-')
print('Avaliador 2:')
print(ordenamento(2, forte_a2, fl_a2))
print(80*'-')
print('Avaliador 3:')
print(ordenamento(3, forte_a3, fl_a3))
print(80*'-')
print('Avaliador 4:')
print(ordenamento(4, forte_a4, fl_a4))
print(80*'-')
print('Avaliador 5:')
print(ordenamento(5, forte_a5, fl_a5))
print(80*'-')
print('Avaliador 6:')
print(ordenamento(6, forte_a6, fl_a6))
print(80*'-')
print('Avaliador 7:')
print(ordenamento(7, forte_a7, fl_a7))
print(80*'-')
print('Avaliador 8:')
print(ordenamento(8, forte_a8, fl_a8))
print(80*'-')
print('Avaliador 9:')
print(ordenamento(9, forte_a9, fl_a9))
print(80*'-')
print('Avaliador 10:')
print(ordenamento(10, forte_a10, fl_a10))
print(80*'-')
print('Avaliador 11:')
print(ordenamento(11, forte_a11, fl_a11))
print(80*'-')
# Out:
# Avaliador 1:
#                                                     Fluxo Líquido  Rank D1
# Equipe multiprofissional com vivências diversif...       0.576667        1
# A centralização na DEAS de processos: produção ...       0.533810        2
# Papel representativo e articulador da área da S...       0.471905        3
# Estrutura de cargos e RH (certificação)                  0.005714        4
# Área física própria                                     -0.026667        5
# O Conselho Executivo facilita a integração dos ...      -0.411429        6
# O modelo de Gestão Centralizada funcionou muito...      -0.486667        7
# Órgãos de Saúde menores se beneficiaram com a c...      -0.663333        8
# --------------------------------------------------------------------------------
# Avaliador 2:
#                                                     Fluxo Líquido  Rank D2
# O Conselho Executivo facilita a integração dos ...       0.776190        1
# Papel representativo e articulador da área da S...       0.481429        2
# A centralização na DEAS de processos: produção ...       0.330000        3
# O modelo de Gestão Centralizada funcionou muito...       0.045714        4
# Equipe multiprofissional com vivências diversif...      -0.042381        5
# Área física própria                                     -0.338571        6
# Estrutura de cargos e RH (certificação)                 -0.586667        7
# Órgãos de Saúde menores se beneficiaram com a c...      -0.665714        8
# --------------------------------------------------------------------------------
# Avaliador 3:
#                                                     Fluxo Líquido  Rank D3
# Equipe multiprofissional com vivências diversif...       0.680476        1
# A centralização na DEAS de processos: produção ...       0.628095        2
# Papel representativo e articulador da área da S...       0.590000        3
# O Conselho Executivo facilita a integração dos ...      -0.016667        4
# Estrutura de cargos e RH (certificação)                 -0.082857        5
# Órgãos de Saúde menores se beneficiaram com a c...      -0.210952        6
# O modelo de Gestão Centralizada funcionou muito...      -0.732381        7
# Área física própria                                     -0.855714        8
# --------------------------------------------------------------------------------
# Avaliador 4:
#                                                     Fluxo Líquido  Rank D4
# Equipe multiprofissional com vivências diversif...       0.302381        1
# A centralização na DEAS de processos: produção ...       0.289048        2
# O Conselho Executivo facilita a integração dos ...       0.270952        3
# O modelo de Gestão Centralizada funcionou muito...       0.206190        4
# Órgãos de Saúde menores se beneficiaram com a c...       0.191905        5
# Papel representativo e articulador da área da S...       0.172857        6
# Estrutura de cargos e RH (certificação)                 -0.452381        7
# Área física própria                                     -0.980952        8
# --------------------------------------------------------------------------------
# Avaliador 5:
#                                                     Fluxo Líquido  Rank D5
# Equipe multiprofissional com vivências diversif...       0.670476        1
# Estrutura de cargos e RH (certificação)                  0.470952        2
# O Conselho Executivo facilita a integração dos ...       0.364762        3
# Papel representativo e articulador da área da S...      -0.115238        4
# O modelo de Gestão Centralizada funcionou muito...      -0.145714        5
# A centralização na DEAS de processos: produção ...      -0.226667        6
# Área física própria                                     -0.315714        7
# Órgãos de Saúde menores se beneficiaram com a c...      -0.702857        8
# --------------------------------------------------------------------------------
# Avaliador 6:
#                                                     Fluxo Líquido  Rank D6
# Papel representativo e articulador da área da S...       0.919048        1
# A centralização na DEAS de processos: produção ...       0.171905        2
# O Conselho Executivo facilita a integração dos ...       0.162857        3
# Equipe multiprofissional com vivências diversif...       0.123333        4
# Estrutura de cargos e RH (certificação)                 -0.031905        5
# Área física própria                                     -0.136667        6
# Órgãos de Saúde menores se beneficiaram com a c...      -0.592381        7
# O modelo de Gestão Centralizada funcionou muito...      -0.616190        8
# --------------------------------------------------------------------------------
# Avaliador 7:
#                                                     Fluxo Líquido  Rank D7
# Papel representativo e articulador da área da S...       0.789048        1
# O Conselho Executivo facilita a integração dos ...       0.400000        2
# A centralização na DEAS de processos: produção ...       0.025238        3
# Equipe multiprofissional com vivências diversif...       0.018095        4
# Estrutura de cargos e RH (certificação)                 -0.062857        5
# O modelo de Gestão Centralizada funcionou muito...      -0.217619        6
# Área física própria                                     -0.347143        7
# Órgãos de Saúde menores se beneficiaram com a c...      -0.604762        8
# --------------------------------------------------------------------------------
# Avaliador 8:
#                                                     Fluxo Líquido  Rank D8
# Papel representativo e articulador da área da S...       0.437143        1
# A centralização na DEAS de processos: produção ...       0.294762        2
# O Conselho Executivo facilita a integração dos ...       0.288571        3
# Equipe multiprofissional com vivências diversif...       0.212857        4
# Estrutura de cargos e RH (certificação)                  0.004286        5
# Área física própria                                      0.004286        6
# O modelo de Gestão Centralizada funcionou muito...      -0.564286        7
# Órgãos de Saúde menores se beneficiaram com a c...      -0.677619        8
# --------------------------------------------------------------------------------
# Avaliador 9:
#                                                     Fluxo Líquido  Rank D9
# Papel representativo e articulador da área da S...       0.392381        1
# O Conselho Executivo facilita a integração dos ...       0.382857        2
# Equipe multiprofissional com vivências diversif...       0.319524        3
# Órgãos de Saúde menores se beneficiaram com a c...       0.152381        4
# O modelo de Gestão Centralizada funcionou muito...       0.131905        5
# Estrutura de cargos e RH (certificação)                  0.115714        6
# A centralização na DEAS de processos: produção ...      -0.509048        7
# Área física própria                                     -0.985714        8
# --------------------------------------------------------------------------------
# Avaliador 10:
#                                                     Fluxo Líquido  Rank D10
# O Conselho Executivo facilita a integração dos ...       0.774286         1
# Papel representativo e articulador da área da S...       0.774286         2
# Equipe multiprofissional com vivências diversif...       0.284286         3
# Estrutura de cargos e RH (certificação)                  0.211429         4
# O modelo de Gestão Centralizada funcionou muito...      -0.419048         5
# A centralização na DEAS de processos: produção ...      -0.419048         6
# Órgãos de Saúde menores se beneficiaram com a c...      -0.596667         7
# Área física própria                                     -0.609524         8
# --------------------------------------------------------------------------------
# Avaliador 11:
#                                                     Fluxo Líquido  Rank D11
# O Conselho Executivo facilita a integração dos ...       0.365714         1
# Papel representativo e articulador da área da S...       0.365714         2
# O modelo de Gestão Centralizada funcionou muito...       0.365714         3
# Equipe multiprofissional com vivências diversif...       0.365714         4
# Órgãos de Saúde menores se beneficiaram com a c...       0.256190         5
# Estrutura de cargos e RH (certificação)                 -0.468571         6
# A centralização na DEAS de processos: produção ...      -0.468571         7
# Área física própria                                     -0.781905         8
# --------------------------------------------------------------------------------

# %%
# generating the tables for each decision-maker (strengths)
ordem_forte_a1 = ordenamento(1, forte_a1, fl_a1)
ordem_forte_a2 = ordenamento(2, forte_a2, fl_a2)
ordem_forte_a3 = ordenamento(3, forte_a3, fl_a3)
ordem_forte_a4 = ordenamento(4, forte_a4, fl_a4)
ordem_forte_a5 = ordenamento(5, forte_a5, fl_a5)
ordem_forte_a6 = ordenamento(6, forte_a6, fl_a6)
ordem_forte_a7 = ordenamento(7, forte_a7, fl_a7)
ordem_forte_a8 = ordenamento(8, forte_a8, fl_a8)
ordem_forte_a9 = ordenamento(9, forte_a9, fl_a9)
ordem_forte_a10 = ordenamento(10, forte_a10, fl_a10)
ordem_forte_a11 = ordenamento(11, forte_a11, fl_a11)

# creating a dataframe with the rankings of all the decision-makers:
pont_fortes = pd.concat([ordem_forte_a1, ordem_forte_a2, ordem_forte_a3, ordem_forte_a4, ordem_forte_a5, ordem_forte_a6, ordem_forte_a7, ordem_forte_a8, ordem_forte_a9, ordem_forte_a10, ordem_forte_a11], axis=1)
pont_fortes = pont_fortes.drop(['Fluxo Líquido'], axis=1)
pont_fortes
# Out:
#                                                     Rank D1  Rank D2  Rank D3  \
# Equipe multiprofissional com vivências diversif...        1        5        1
# A centralização na DEAS de processos: produção ...        2        3        2
# Papel representativo e articulador da área da S...        3        2        3
# Estrutura de cargos e RH (certificação)                   4        7        5
# Área física própria                                       5        6        8
# O Conselho Executivo facilita a integração dos ...        6        1        4
# O modelo de Gestão Centralizada funcionou muito...        7        4        7
# Órgãos de Saúde menores se beneficiaram com a c...        8        8        6
#
#                                                     Rank D4  Rank D5  Rank D6  \
# Equipe multiprofissional com vivências diversif...        1        1        4
# A centralização na DEAS de processos: produção ...        2        6        2
# Papel representativo e articulador da área da S...        6        4        1
# Estrutura de cargos e RH (certificação)                   7        2        5
# Área física própria                                       8        7        6
# O Conselho Executivo facilita a integração dos ...        3        3        3
# O modelo de Gestão Centralizada funcionou muito...        4        5        8
# Órgãos de Saúde menores se beneficiaram com a c...        5        8        7
#
#                                                     Rank D7  Rank D8  Rank D9  \
# Equipe multiprofissional com vivências diversif...        4        4        3
# A centralização na DEAS de processos: produção ...        3        2        7
# Papel representativo e articulador da área da S...        1        1        1
# Estrutura de cargos e RH (certificação)                   5        5        6
# Área física própria                                       7        6        8
# O Conselho Executivo facilita a integração dos ...        2        3        2
# O modelo de Gestão Centralizada funcionou muito...        6        7        5
# Órgãos de Saúde menores se beneficiaram com a c...        8        8        4
#
#                                                     Rank D10  Rank D11
# Equipe multiprofissional com vivências diversif...         3         4
# A centralização na DEAS de processos: produção ...         6         7
# Papel representativo e articulador da área da S...         2         2
# Estrutura de cargos e RH (certificação)                    4         6
# Área física própria                                        8         8
# O Conselho Executivo facilita a integração dos ...         1         1
# O modelo de Gestão Centralizada funcionou muito...         5         3
# Órgãos de Saúde menores se beneficiaram com a c...         7         5

# %% [markdown]
# ## Group Decision (Borda):

# %%
# creating a border scale
borda_forte = {}
for i in range(0, len(pont_fortes)):
  borda_forte.update({i+1: (len(pont_fortes)-i)})

peso_dirigente = 1.2
borda_forte_dirig = {}
for i in range(0, len(pont_fortes)):
  borda_forte_dirig.update({i+1: (len(pont_fortes)-i)*peso_dirigente})

# replacing the sort values with the Edge scale value
# Ex: (1,2,3) will become (3,2,1)
for i in pont_fortes.columns:
  if i == pont_fortes.columns[0]: # if the decision-maker is the manager (greater weight)
    pont_fortes[i] = pont_fortes[i].map(borda_forte_dirig)
  else:
    pont_fortes[i] = pont_fortes[i].map(borda_forte)

# adding up the values of each alternative
pont_fortes['Valor'] = pont_fortes.sum(axis=1)

pont_fortes_final = pd.DataFrame(pont_fortes['Valor'])
pont_fortes_final = pont_fortes_final.sort_values(by='Valor', ascending=False)

ord = []
for i in range(0, len(pont_fortes_final)):
  ord.append(f'{i+1}°')

pont_fortes_final['Ordem Final (Borda)'] = ord
pont_fortes_final
# Out:
#                                                     Valor Ordem Final (Borda)
# Papel representativo e articulador da área da S...   74.2                  1°
# O Conselho Executivo facilita a integração dos ...   70.6                  2°
# Equipe multiprofissional com vivências diversif...   69.6                  3°
# A centralização na DEAS de processos: produção ...   58.4                  4°
# Estrutura de cargos e RH (certificação)              44.0                  5°
# O modelo de Gestão Centralizada funcionou muito...   38.4                  6°
# Órgãos de Saúde menores se beneficiaram com a c...   25.2                  7°
# Área física própria                                  22.8                  8°

# %% [markdown]
# ## Group Decision (Condorcet):

# %%
ordem_forte_a1 = ordenamento(1, forte_a1, fl_a1)
ordem_forte_a2 = ordenamento(2, forte_a2, fl_a2)
ordem_forte_a3 = ordenamento(3, forte_a3, fl_a3)
ordem_forte_a4 = ordenamento(4, forte_a4, fl_a4)

candidatos = ordem_forte_a1.index.values
candidatos = list(candidatos)

lista_forte = [ordem_forte_a1, ordem_forte_a2, ordem_forte_a3, ordem_forte_a4]
votos = voto(lista_forte)

# using condorcet library functions to define sorting
evaluator = condorcet.CondorcetEvaluator(candidates=candidatos, votes=votos)
winners, rest_of_table = evaluator.get_n_winners(len(ordem_forte_a1))

forte_condorcet = pd.DataFrame(index=winners)

ord = []
for i in range(0, len(forte_condorcet)):
  ord.append(f'{i+1}°')
forte_condorcet['Ordem Final (Condorcet)'] = ord

forte_condorcet
# Out:
#                                                    Ordem Final (Condorcet)
# Equipe multiprofissional com vivências diversif...                      1°
# A centralização na DEAS de processos: produção ...                      2°
# Papel representativo e articulador da área da S...                      3°
# O Conselho Executivo facilita a integração dos ...                      4°
# Estrutura de cargos e RH (certificação)                                 5°
# O modelo de Gestão Centralizada funcionou muito...                      6°
# Área física própria                                                     7°
# Órgãos de Saúde menores se beneficiaram com a c...                      8°
